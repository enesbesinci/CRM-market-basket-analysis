# %%
import pandas as pd
import random

from datetime import datetime, timedelta

from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

random.seed(42)

# %%
# List of different products (17 items)
all_items = ['BREAD', 'TEA', 'COKE', 'JAM', 'MAGGI', 'MILK', 'ORANGE', 'CORNFLAKES', 'SUGAR', 'COFFEE',
             'RICE', 'FLOUR', 'SALT', 'PEPPER', 'BUTTER', 'EGGS', 'YOGURT']

# Istanbul districts
istanbul_districts = ['Kadıköy', 'Beşiktaş', 'Şişli', 'Bakırköy', 'Üsküdar', 'Sarıyer', 'Ataşehir', 'Fatih', 'Eyüp', 'Bağcılar']

# Payment methods
payment_methods = ['Credit Card', 'Debit Card', 'Cash']

# Create a dataset
data = {'OrderNumber': [], 'OrderDate': [], 'OrderTime': [], 'District': [], 'Customer_ID': [], 'PaymentMethod': [], 'Items': []}

num_transactions = 10000  # Total number of rows
max_items_per_transaction = 10  # Maximum number of items per row
max_rows_per_customer = 4  # Maximum number of rows per customer

# Add customer data for a total of 400 customers
customer_ids = [str(random.randint(10000, 99999)) for _ in range(10000)]
random.shuffle(customer_ids)

for customer_id in customer_ids:
    customer_rows = min(random.randint(1, max_rows_per_customer), num_transactions - len(data['OrderNumber']))
    
    for _ in range(customer_rows):
        # Randomly select a number of items for each row
        num_items = random.randint(3, max_items_per_transaction)
        items = random.sample(all_items, k=num_items)

        # Add a random order date and time
        order_date = datetime(2023, 1, 1) + timedelta(days=random.randint(1, 365))
        order_time = datetime.strptime(f"{random.randint(0, 23):02d}:{random.randint(0, 59):02d}", "%H:%M")

        data['OrderDate'].append(order_date.strftime("%Y-%m-%d"))
        data['OrderTime'].append(order_time.strftime("%H:%M"))

        # Add an Istanbul district
        data['District'].append(random.choice(istanbul_districts))
        data['OrderNumber'].append(random.randint(1000, 9999))
        data['Customer_ID'].append(customer_id)
        data['PaymentMethod'].append(random.choice(payment_methods))
        data['Items'].append(','.join(items))

        if len(data['OrderNumber']) == num_transactions:
            break

# Create a DataFrame
df = pd.DataFrame(data)

# Sort the DataFrame by "OrderNumber"
# df.sort_values(by='OrderNumber', inplace=True)

# Reorder the columns
df = df[['Customer_ID', 'OrderNumber', 'OrderDate', 'OrderTime', 'District', 'PaymentMethod', 'Items']]

# save the dataframe as a csv file
df.to_csv("market_transaction_data.csv", index=False)

# %%
# Display the created DataFrame
df.head()
# Out:
#   Customer_ID  OrderNumber   OrderDate OrderTime  District PaymentMethod  \
# 0       34371         4508  2023-08-17     08:20   Üsküdar          Cash
# 1       34371         2889  2023-07-13     17:29  Beşiktaş          Cash
# 2       34371         3215  2023-02-28     17:30  Ataşehir   Credit Card
# 3       34371         4956  2023-11-08     17:56  Beşiktaş          Cash
# 4       25970         3289  2023-01-24     13:31  Bakırköy   Credit Card
#
#                                            Items
# 0               ORANGE,BUTTER,YOGURT,COKE,COFFEE
# 1                              ORANGE,SALT,MAGGI
# 2              TEA,CORNFLAKES,FLOUR,BUTTER,SUGAR
# 3               CORNFLAKES,MAGGI,JAM,BREAD,SUGAR
# 4  YOGURT,COKE,MAGGI,BUTTER,MILK,SUGAR,EGGS,RICE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    10000 non-null  object
#  1   OrderNumber    10000 non-null  int64
#  2   OrderDate      10000 non-null  object
#  3   OrderTime      10000 non-null  object
#  4   District       10000 non-null  object
#  5   PaymentMethod  10000 non-null  object
#  6   Items          10000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 547.0+ KB

# %%
product_data = list(df["Items"].apply(lambda x:x.split(",")))
product_data
# Out:
# [['ORANGE', 'BUTTER', 'YOGURT', 'COKE', 'COFFEE'],
#  ['ORANGE', 'SALT', 'MAGGI'],
#  ['TEA', 'CORNFLAKES', 'FLOUR', 'BUTTER', 'SUGAR'],
#  ['CORNFLAKES', 'MAGGI', 'JAM', 'BREAD', 'SUGAR'],
#  ['YOGURT', 'COKE', 'MAGGI', 'BUTTER', 'MILK', 'SUGAR', 'EGGS', 'RICE'],
#  ['BUTTER', 'COKE', 'ORANGE', 'FLOUR', 'RICE'],
#  ['BREAD', 'TEA', 'SALT', 'YOGURT', 'BUTTER', 'PEPPER', 'RICE', 'FLOUR'],
#  ['EGGS', 'JAM', 'CORNFLAKES', 'SALT', 'SUGAR', 'RICE'],
#  ['FLOUR', 'RICE', 'ORANGE', 'EGGS', 'TEA'],
#  ['EGGS', 'COFFEE', 'CORNFLAKES', 'SUGAR', 'SALT'],
#  ['SALT', 'EGGS', 'BREAD', 'SUGAR', 'ORANGE', 'CORNFLAKES', 'BUTTER', 'RICE'],
#  ['COKE', 'FLOUR', 'EGGS', 'SUGAR', 'MAGGI', 'PEPPER', 'YOGURT', 'ORANGE'],
#  ['YOGURT', 'CORNFLAKES', 'MILK', 'BUTTER', 'RICE', 'BREAD', 'PEPPER'],
#  ['TEA', 'EGGS', 'BREAD'],
#  ['YOGURT', 'MILK', 'COKE'],
#  ['YOGURT', 'JAM', 'BUTTER', 'SUGAR', 'PEPPER', 'FLOUR', 'BREAD'],
#  ['EGGS',
#   'CORNFLAKES',
#   'SUGAR',
#   'JAM',
#   'ORANGE',
#   'FLOUR',
#   'PEPPER',
#   'BUTTER',
#   'TEA',
#   'SALT'],
#  ['MILK', 'COFFEE', 'ORANGE', 'MAGGI', 'COKE', 'BREAD', 'JAM'],
#  ['JAM', 'COFFEE', 'SALT', 'MAGGI', 'TEA', 'CORNFLAKES'],
#  ['COFFEE', 'TEA', 'COKE', 'ORANGE', 'SALT', 'JAM', 'RICE', 'MILK'],
#  ['COKE', 'EGGS', 'ORANGE'],
#  ['JAM', 'FLOUR', 'YOGURT', 'SUGAR', 'EGGS', 'PEPPER'],
#  ['TEA',
#   'RICE',
#   'BREAD',
#   'MAGGI',
#   'EGGS',
#   'SALT',
#   'BUTTER',
#   'PEPPER',
#   'JAM',
#   'SUGAR'],
#  ['RICE', 'JAM', 'ORANGE', 'FLOUR', 'EGGS', 'COKE', 'TEA'],
#  ['TEA', 'ORANGE', 'JAM', 'COFFEE'],
#  ['SALT', 'RICE', 'JAM', 'BREAD', 'ORANGE'],
#  ['SALT', 'JAM', 'CORNFLAKES', 'SUGAR', 'ORANGE', 'PEPPER', 'FLOUR', 'BREAD'],
#  ['RICE', 'PEPPER', 'TEA', 'SUGAR'],
#  ['EGGS', 'YOGURT', 'MAGGI', 'FLOUR', 'BUTTER', 'COFFEE', 'TEA', 'ORANGE'],
#  ['MAGGI', 'TEA', 'EGGS', 'YOGURT', 'COFFEE', 'BUTTER', 'FLOUR', 'SUGAR'],
#  ['CORNFLAKES', 'SALT', 'SUGAR', 'YOGURT', 'MILK', 'BREAD'],
#  ['ORANGE', 'MAGGI', 'TEA', 'JAM', 'CORNFLAKES'],
#  ['COFFEE', 'MAGGI', 'SUGAR'],
#  ['RICE', 'CORNFLAKES', 'EGGS'],
#  ['JAM', 'MAGGI', 'ORANGE', 'SALT'],
#  ['SALT',
#   'COKE',
#   'PEPPER',
#   'BUTTER',
#   'YOGURT',
#   'BREAD',
#   'ORANGE',
#   'EGGS',
#   'CORNFLAKES'],
#  ['SUGAR', 'RICE', 'MILK', 'BREAD', 'ORANGE', 'YOGURT'],
#  ['PEPPER',
#   'MAGGI',
#   'COFFEE',
#   'JAM',
#   'SUGAR',
#   'EGGS',
#   'FLOUR',
#   'BREAD',
#   'TEA',
#   'YOGURT'],
#  ['CORNFLAKES', 'EGGS', 'PEPPER', 'RICE', 'SUGAR', 'FLOUR', 'SALT'],
#  ['JAM', 'TEA', 'EGGS', 'RICE', 'MILK', 'CORNFLAKES', 'BREAD', 'COFFEE'],
#  ['MILK', 'BREAD', 'FLOUR', 'CORNFLAKES', 'MAGGI', 'COFFEE', 'COKE'],
#  ['BUTTER', 'COKE', 'YOGURT', 'SUGAR', 'MAGGI', 'EGGS', 'PEPPER'],
#  ['JAM', 'COFFEE', 'BREAD', 'SALT', 'SUGAR', 'MAGGI', 'EGGS', 'RICE'],
#  ['COFFEE', 'MAGGI', 'SALT', 'ORANGE', 'PEPPER', 'YOGURT'],
#  ['MAGGI',
#   'SALT',
#   'RICE',
#   'TEA',
#   'CORNFLAKES',
#   'ORANGE',
#   'BREAD',
#   'EGGS',
#   'COKE',
#   'JAM'],
#  ['FLOUR', 'CORNFLAKES', 'BUTTER', 'SUGAR', 'COKE', 'RICE', 'PEPPER', 'BREAD'],
#  ['MAGGI', 'PEPPER', 'MILK', 'BREAD'],
#  ['SUGAR',
#   'COKE',
#   'SALT',
#   'YOGURT',
#   'ORANGE',
#   'COFFEE',
#   'BUTTER',
#   'MILK',
#   'RICE'],
#  ['PEPPER',
#   'JAM',
#   'RICE',
#   'YOGURT',
#   'BUTTER',
#   'COKE',
#   'EGGS',
#   'SUGAR',
#   'MILK',
#   'COFFEE'],
#  ['COFFEE', 'SUGAR', 'RICE', 'BREAD', 'PEPPER', 'COKE'],
#  ['SALT',
#   'COKE',
#   'BREAD',
#   'TEA',
#   'YOGURT',
#   'ORANGE',
#   'SUGAR',
#   'JAM',
#   'PEPPER'],
#  ['SALT', 'TEA', 'COFFEE', 'RICE'],
#  ['BUTTER', 'PEPPER', 'SALT'],
#  ['MAGGI', 'TEA', 'FLOUR', 'MILK', 'JAM', 'RICE', 'YOGURT', 'BUTTER', 'BREAD'],
#  ['TEA', 'BUTTER', 'EGGS', 'COKE', 'FLOUR'],
#  ['EGGS', 'YOGURT', 'BUTTER', 'ORANGE'],
#  ['YOGURT',
#   'SUGAR',
#   'TEA',
#   'JAM',
#   'PEPPER',
#   'SALT',
#   'CORNFLAKES',
#   'FLOUR',
#   'BUTTER'],
#  ['BUTTER', 'COKE', 'CORNFLAKES', 'BREAD'],
#  ['BREAD', 'SALT', 'TEA', 'JAM', 'EGGS'],
#  ['EGGS',
#   'FLOUR',
#   'ORANGE',
#   'TEA',
#   'JAM',
#   'SALT',
#   'CORNFLAKES',
#   'PEPPER',
#   'SUGAR',
#   'MAGGI'],
#  ['TEA', 'MAGGI', 'PEPPER', 'ORANGE', 'EGGS', 'SUGAR', 'BREAD', 'YOGURT'],
#  ['JAM', 'SALT', 'CORNFLAKES', 'SUGAR', 'TEA', 'COKE', 'BUTTER'],
#  ['MILK', 'COKE', 'BUTTER'],
#  ['YOGURT', 'PEPPER', 'COKE', 'COFFEE', 'SUGAR', 'MILK', 'CORNFLAKES'],
#  ['JAM', 'MILK', 'SUGAR', 'RICE', 'EGGS', 'ORANGE'],
#  ['PEPPER',
#   'SALT',
#   'RICE',
#   'TEA',
#   'CORNFLAKES',
#   'EGGS',
#   'BREAD',
#   'ORANGE',
#   'FLOUR',
#   'JAM'],
#  ['MAGGI', 'COKE', 'RICE', 'PEPPER', 'EGGS', 'SALT', 'JAM', 'MILK', 'COFFEE'],
#  ['JAM',
#   'SUGAR',
#   'ORANGE',
#   'COFFEE',
#   'COKE',
#   'FLOUR',
#   'TEA',
#   'EGGS',
#   'SALT',
#   'RICE'],
#  ['SUGAR', 'CORNFLAKES', 'ORANGE'],
#  ['MAGGI', 'TEA', 'PEPPER', 'MILK', 'SALT'],
#  ['MAGGI', 'COFFEE', 'BUTTER', 'EGGS', 'MILK', 'FLOUR', 'PEPPER'],
#  ['BUTTER', 'YOGURT', 'SALT', 'EGGS', 'BREAD', 'FLOUR', 'RICE', 'CORNFLAKES'],
#  ['BUTTER',
#   'SALT',
#   'CORNFLAKES',
#   'JAM',
#   'SUGAR',
#   'RICE',
#   'COKE',
#   'BREAD',
#   'YOGURT'],
#  ['EGGS',
#   'SALT',
#   'SUGAR',
#   'COKE',
#   'COFFEE',
#   'YOGURT',
#   'ORANGE',
#   'BUTTER',
#   'CORNFLAKES',
#   'PEPPER'],
#  ['RICE', 'BREAD', 'ORANGE'],
#  ['BREAD', 'FLOUR', 'SALT', 'ORANGE', 'PEPPER', 'EGGS', 'COFFEE'],
#  ['MILK', 'SUGAR', 'BUTTER', 'EGGS'],
#  ['BUTTER',
#   'SALT',
#   'JAM',
#   'COKE',
#   'MILK',
#   'COFFEE',
#   'MAGGI',
#   'PEPPER',
#   'YOGURT'],
#  ['ORANGE', 'JAM', 'MILK', 'YOGURT', 'COKE', 'MAGGI'],
#  ['MILK',
#   'RICE',
#   'ORANGE',
#   'COKE',
#   'COFFEE',
#   'PEPPER',
#   'BUTTER',
#   'SALT',
#   'JAM',
#   'SUGAR'],
#  ['SALT', 'FLOUR', 'MILK', 'BREAD'],
#  ['BREAD', 'RICE', 'SALT', 'CORNFLAKES', 'BUTTER', 'EGGS', 'MAGGI', 'FLOUR'],
#  ['EGGS', 'YOGURT', 'COKE', 'BREAD'],
#  ['FLOUR', 'ORANGE', 'EGGS', 'MAGGI'],
#  ['JAM', 'ORANGE', 'FLOUR', 'COKE', 'MILK', 'COFFEE'],
#  ['BUTTER',
#   'RICE',
#   'BREAD',
#   'YOGURT',
#   'COFFEE',
#   'MAGGI',
#   'COKE',
#   'TEA',
#   'FLOUR'],
#  ['YOGURT',
#   'JAM',
#   'FLOUR',
#   'COFFEE',
#   'SUGAR',
#   'CORNFLAKES',
#   'SALT',
#   'BREAD',
#   'COKE'],
#  ['MILK',
#   'MAGGI',
#   'BUTTER',
#   'YOGURT',
#   'SUGAR',
#   'ORANGE',
#   'FLOUR',
#   'BREAD',
#   'PEPPER'],
#  ['COFFEE', 'MILK', 'COKE', 'CORNFLAKES', 'FLOUR', 'EGGS', 'SUGAR'],
#  ['PEPPER', 'FLOUR', 'SALT', 'YOGURT', 'MILK', 'EGGS', 'COFFEE', 'MAGGI'],
#  ['BREAD', 'MAGGI', 'BUTTER', 'PEPPER', 'YOGURT', 'SALT', 'FLOUR', 'COKE'],
#  ['MAGGI', 'JAM', 'SALT', 'MILK', 'PEPPER', 'TEA'],
#  ['PEPPER', 'MILK', 'RICE', 'TEA', 'MAGGI', 'SALT'],
#  ['MAGGI',
#   'EGGS',
#   'PEPPER',
#   'FLOUR',
#   'JAM',
#   'ORANGE',
#   'CORNFLAKES',
#   'RICE',
#   'YOGURT',
#   'BUTTER'],
#  ['COFFEE', 'ORANGE', 'TEA', 'SUGAR', 'JAM', 'COKE', 'PEPPER', 'BUTTER'],
#  ['BREAD', 'COFFEE', 'EGGS', 'TEA', 'YOGURT'],
#  ['EGGS', 'MILK', 'JAM', 'FLOUR', 'SUGAR', 'CORNFLAKES', 'YOGURT'],
#  ['BUTTER', 'MILK', 'SALT', 'COKE'],
#  ['SUGAR', 'EGGS', 'COKE', 'ORANGE', 'BUTTER', 'COFFEE', 'BREAD', 'MILK'],
#  ['JAM', 'SALT', 'BREAD', 'SUGAR', 'COKE', 'FLOUR'],
#  ['ORANGE', 'BUTTER', 'SALT', 'FLOUR', 'PEPPER', 'JAM'],
#  ['MILK', 'MAGGI', 'COFFEE', 'BUTTER', 'PEPPER'],
#  ['RICE', 'COKE', 'YOGURT', 'MAGGI', 'JAM', 'SUGAR', 'FLOUR', 'EGGS', 'SALT'],
#  ['RICE', 'COFFEE', 'MAGGI', 'ORANGE', 'TEA', 'CORNFLAKES'],
#  ['CORNFLAKES', 'BREAD', 'COFFEE', 'MILK', 'MAGGI', 'SALT', 'BUTTER'],
#  ['BREAD',
#   'MILK',
#   'COFFEE',
#   'COKE',
#   'CORNFLAKES',
#   'TEA',
#   'PEPPER',
#   'YOGURT',
#   'EGGS',
#   'JAM'],
#  ['ORANGE', 'EGGS', 'FLOUR', 'PEPPER'],
#  ['MAGGI', 'BREAD', 'SALT', 'RICE', 'BUTTER'],
#  ['MILK', 'TEA', 'BUTTER', 'BREAD', 'MAGGI', 'SUGAR'],
#  ['ORANGE', 'FLOUR', 'RICE', 'SUGAR', 'MILK', 'COKE', 'JAM', 'PEPPER'],
#  ['COFFEE', 'CORNFLAKES', 'BUTTER', 'ORANGE', 'RICE', 'TEA', 'YOGURT'],
#  ['ORANGE', 'COKE', 'BREAD', 'SALT', 'EGGS'],
#  ['COKE', 'COFFEE', 'JAM'],
#  ['PEPPER', 'EGGS', 'TEA'],
#  ['MAGGI', 'SALT', 'BREAD', 'RICE'],
#  ['PEPPER',
#   'BUTTER',
#   'SALT',
#   'RICE',
#   'COKE',
#   'BREAD',
#   'TEA',
#   'COFFEE',
#   'YOGURT',
#   'SUGAR'],
#  ['TEA', 'BUTTER', 'COKE', 'FLOUR'],
#  ['TEA', 'COFFEE', 'EGGS', 'JAM', 'ORANGE', 'SALT'],
#  ['YOGURT', 'JAM', 'COKE', 'SALT', 'PEPPER', 'MAGGI', 'BUTTER'],
#  ['BREAD', 'RICE', 'COKE', 'BUTTER', 'COFFEE', 'MAGGI', 'ORANGE', 'PEPPER'],
#  ['COKE', 'BREAD', 'SALT', 'JAM', 'FLOUR', 'RICE', 'COFFEE', 'BUTTER', 'MILK'],
#  ['JAM',
#   'MAGGI',
#   'EGGS',
#   'YOGURT',
#   'ORANGE',
#   'MILK',
#   'SUGAR',
#   'FLOUR',
#   'RICE',
#   'COFFEE'],
#  ['COKE', 'MAGGI', 'BREAD', 'YOGURT', 'CORNFLAKES', 'BUTTER', 'ORANGE'],
#  ['TEA', 'MILK', 'COFFEE', 'BUTTER', 'BREAD', 'CORNFLAKES', 'YOGURT'],
#  ['MAGGI', 'YOGURT', 'PEPPER', 'EGGS', 'SUGAR', 'RICE'],
#  ['CORNFLAKES', 'COFFEE', 'BREAD'],
#  ['BUTTER',
#   'FLOUR',
#   'ORANGE',
#   'SALT',
#   'MAGGI',
#   'COFFEE',
#   'TEA',
#   'MILK',
#   'CORNFLAKES',
#   'EGGS'],
#  ['MAGGI', 'SUGAR', 'CORNFLAKES', 'ORANGE'],
#  ['TEA', 'ORANGE', 'BREAD', 'SALT'],
#  ['COKE', 'EGGS', 'YOGURT', 'ORANGE', 'SUGAR', 'BREAD', 'SALT'],
#  ['BREAD', 'JAM', 'MILK', 'FLOUR', 'YOGURT'],
#  ['CORNFLAKES', 'TEA', 'YOGURT', 'FLOUR'],
#  ['EGGS', 'COFFEE', 'JAM', 'SALT', 'ORANGE', 'COKE', 'TEA'],
#  ['YOGURT',
#   'FLOUR',
#   'CORNFLAKES',
#   'ORANGE',
#   'EGGS',
#   'PEPPER',
#   'COFFEE',
#   'MAGGI'],
#  ['ORANGE', 'SALT', 'COKE', 'PEPPER', 'EGGS', 'CORNFLAKES'],
#  ['COKE', 'CORNFLAKES', 'PEPPER', 'YOGURT', 'FLOUR', 'EGGS', 'BREAD', 'RICE'],
#  ['BREAD', 'COKE', 'SALT', 'TEA', 'YOGURT', 'CORNFLAKES', 'COFFEE', 'FLOUR'],
#  ['CORNFLAKES', 'COKE', 'PEPPER', 'FLOUR', 'COFFEE', 'BUTTER', 'RICE'],
#  ['RICE', 'MILK', 'BREAD', 'MAGGI'],
#  ['YOGURT',
#   'EGGS',
#   'RICE',
#   'JAM',
#   'BUTTER',
#   'TEA',
#   'PEPPER',
#   'CORNFLAKES',
#   'COFFEE'],
#  ['JAM', 'PEPPER', 'BUTTER', 'ORANGE', 'TEA', 'COKE', 'YOGURT'],
#  ['CORNFLAKES', 'YOGURT', 'PEPPER', 'COKE', 'SALT', 'MILK', 'ORANGE'],
#  ['BUTTER', 'BREAD', 'TEA', 'FLOUR'],
#  ['TEA',
#   'BUTTER',
#   'PEPPER',
#   'SUGAR',
#   'COKE',
#   'YOGURT',
#   'FLOUR',
#   'ORANGE',
#   'BREAD',
#   'SALT'],
#  ['CORNFLAKES', 'FLOUR', 'RICE', 'EGGS'],
#  ['JAM', 'COKE', 'CORNFLAKES', 'BREAD', 'FLOUR'],
#  ['COKE', 'SALT', 'BUTTER'],
#  ['FLOUR',
#   'CORNFLAKES',
#   'COFFEE',
#   'EGGS',
#   'SUGAR',
#   'MILK',
#   'PEPPER',
#   'BREAD',
#   'SALT',
#   'COKE'],
#  ['RICE',
#   'EGGS',
#   'YOGURT',
#   'TEA',
#   'COKE',
#   'JAM',
#   'ORANGE',
#   'COFFEE',
#   'PEPPER',
#   'MAGGI'],
#  ['MILK', 'PEPPER', 'SUGAR', 'BUTTER', 'COKE', 'CORNFLAKES', 'ORANGE'],
#  ['FLOUR', 'CORNFLAKES', 'YOGURT'],
#  ['PEPPER', 'TEA', 'CORNFLAKES', 'SUGAR', 'RICE', 'JAM', 'COKE', 'BUTTER'],
#  ['FLOUR',
#   'JAM',
#   'SALT',
#   'CORNFLAKES',
#   'COFFEE',
#   'RICE',
#   'YOGURT',
#   'ORANGE',
#   'COKE'],
#  ['SALT',
#   'CORNFLAKES',
#   'FLOUR',
#   'MAGGI',
#   'COFFEE',
#   'ORANGE',
#   'BREAD',
#   'PEPPER',
#   'EGGS'],
#  ['RICE', 'JAM', 'ORANGE', 'COKE', 'PEPPER'],
#  ['BREAD', 'CORNFLAKES', 'MAGGI', 'SUGAR', 'ORANGE'],
#  ['SALT', 'EGGS', 'COKE', 'YOGURT', 'SUGAR', 'CORNFLAKES', 'COFFEE'],
#  ['COKE', 'ORANGE', 'PEPPER', 'TEA', 'COFFEE', 'FLOUR', 'JAM'],
#  ['CORNFLAKES', 'ORANGE', 'YOGURT', 'FLOUR'],
#  ['RICE', 'JAM', 'ORANGE', 'MILK', 'SALT', 'FLOUR', 'BREAD'],
#  ['SUGAR', 'JAM', 'COFFEE', 'TEA', 'ORANGE'],
#  ['PEPPER', 'SALT', 'YOGURT'],
#  ['TEA', 'BREAD', 'PEPPER', 'ORANGE', 'CORNFLAKES', 'SUGAR', 'COKE'],
#  ['CORNFLAKES', 'RICE', 'COFFEE', 'COKE'],
#  ['BUTTER',
#   'COFFEE',
#   'YOGURT',
#   'SUGAR',
#   'ORANGE',
#   'EGGS',
#   'MAGGI',
#   'TEA',
#   'MILK'],
#  ['MAGGI', 'MILK', 'BREAD', 'PEPPER'],
#  ['JAM', 'COKE', 'CORNFLAKES', 'TEA', 'ORANGE', 'RICE', 'BREAD', 'YOGURT'],
#  ['CORNFLAKES', 'PEPPER', 'FLOUR', 'RICE', 'COKE', 'TEA', 'SUGAR', 'COFFEE'],
#  ['BREAD',
#   'TEA',
#   'YOGURT',
#   'COFFEE',
#   'RICE',
#   'SALT',
#   'PEPPER',
#   'MAGGI',
#   'COKE',
#   'FLOUR'],
#  ['SALT',
#   'SUGAR',
#   'YOGURT',
#   'FLOUR',
#   'EGGS',
#   'COFFEE',
#   'ORANGE',
#   'RICE',
#   'CORNFLAKES'],
#  ['COFFEE', 'RICE', 'ORANGE'],
#  ['COFFEE',
#   'RICE',
#   'JAM',
#   'BUTTER',
#   'SALT',
#   'SUGAR',
#   'YOGURT',
#   'BREAD',
#   'ORANGE',
#   'COKE'],
#  ['RICE',
#   'COFFEE',
#   'BREAD',
#   'TEA',
#   'ORANGE',
#   'YOGURT',
#   'MILK',
#   'EGGS',
#   'FLOUR'],
#  ['MILK', 'MAGGI', 'EGGS', 'COKE'],
#  ['RICE', 'COKE', 'ORANGE', 'BREAD', 'TEA'],
#  ['YOGURT', 'SALT', 'BREAD', 'BUTTER', 'EGGS', 'SUGAR', 'PEPPER'],
#  ['MAGGI',
#   'ORANGE',
#   'PEPPER',
#   'TEA',
#   'COKE',
#   'COFFEE',
#   'FLOUR',
#   'MILK',
#   'CORNFLAKES',
#   'BREAD'],
#  ['COKE', 'MAGGI', 'FLOUR', 'TEA', 'YOGURT', 'BREAD', 'JAM', 'SUGAR', 'EGGS'],
#  ['SALT', 'TEA', 'CORNFLAKES', 'SUGAR', 'MILK', 'RICE', 'COKE', 'YOGURT'],
#  ['YOGURT', 'RICE', 'BUTTER', 'MAGGI', 'MILK', 'PEPPER'],
#  ['COFFEE', 'BUTTER', 'MILK', 'FLOUR', 'COKE', 'JAM', 'TEA', 'RICE'],
#  ['COKE',
#   'BUTTER',
#   'CORNFLAKES',
#   'SALT',
#   'ORANGE',
#   'JAM',
#   'FLOUR',
#   'MAGGI',
#   'YOGURT',
#   'EGGS'],
#  ['EGGS', 'FLOUR', 'YOGURT', 'BREAD'],
#  ['SUGAR', 'RICE', 'FLOUR'],
#  ['CORNFLAKES', 'RICE', 'PEPPER', 'JAM', 'MAGGI', 'BREAD', 'FLOUR'],
#  ['BUTTER',
#   'EGGS',
#   'SUGAR',
#   'MAGGI',
#   'YOGURT',
#   'TEA',
#   'ORANGE',
#   'MILK',
#   'COKE'],
#  ['ORANGE', 'FLOUR', 'EGGS'],
#  ['BREAD', 'RICE', 'JAM', 'EGGS'],
#  ['SALT', 'PEPPER', 'COFFEE', 'SUGAR', 'EGGS', 'COKE', 'BUTTER'],
#  ['SUGAR', 'BUTTER', 'RICE', 'COKE'],
#  ['MILK', 'SUGAR', 'COKE', 'JAM', 'EGGS', 'RICE', 'PEPPER'],
#  ['MAGGI', 'JAM', 'RICE', 'BUTTER'],
#  ['MILK', 'TEA', 'FLOUR', 'COFFEE', 'SUGAR', 'JAM'],
#  ['CORNFLAKES', 'MILK', 'BUTTER', 'BREAD', 'PEPPER'],
#  ['TEA', 'BREAD', 'SUGAR', 'PEPPER'],
#  ['JAM',
#   'BREAD',
#   'SUGAR',
#   'TEA',
#   'MAGGI',
#   'YOGURT',
#   'MILK',
#   'ORANGE',
#   'PEPPER'],
#  ['COKE', 'TEA', 'SALT', 'CORNFLAKES', 'MAGGI', 'ORANGE'],
#  ['RICE',
#   'JAM',
#   'BREAD',
#   'BUTTER',
#   'EGGS',
#   'FLOUR',
#   'PEPPER',
#   'CORNFLAKES',
#   'ORANGE'],
#  ['COKE',
#   'RICE',
#   'BREAD',
#   'FLOUR',
#   'BUTTER',
#   'ORANGE',
#   'PEPPER',
#   'EGGS',
#   'COFFEE',
#   'MAGGI'],
#  ['COKE', 'CORNFLAKES', 'MAGGI', 'BREAD'],
#  ['EGGS', 'TEA', 'SUGAR', 'COFFEE', 'BREAD', 'MILK', 'BUTTER'],
#  ['SALT', 'YOGURT', 'COKE', 'ORANGE', 'COFFEE'],
#  ['YOGURT',
#   'EGGS',
#   'SALT',
#   'COFFEE',
#   'TEA',
#   'MILK',
#   'BREAD',
#   'FLOUR',
#   'ORANGE',
#   'COKE'],
#  ['MAGGI', 'BREAD', 'TEA', 'COKE', 'ORANGE', 'FLOUR'],
#  ['COKE', 'BREAD', 'SALT', 'COFFEE', 'MILK', 'YOGURT', 'TEA'],
#  ['BUTTER',
#   'COFFEE',
#   'FLOUR',
#   'TEA',
#   'RICE',
#   'YOGURT',
#   'COKE',
#   'CORNFLAKES',
#   'MAGGI',
#   'ORANGE'],
#  ['SUGAR', 'COKE', 'COFFEE', 'FLOUR', 'BUTTER'],
#  ['EGGS', 'RICE', 'SUGAR', 'COFFEE', 'TEA'],
#  ['JAM', 'FLOUR', 'RICE', 'MAGGI', 'MILK'],
#  ['MAGGI', 'FLOUR', 'CORNFLAKES', 'PEPPER', 'BREAD'],
#  ['RICE', 'PEPPER', 'MAGGI', 'BREAD', 'CORNFLAKES', 'COKE'],
#  ['RICE', 'SUGAR', 'BREAD', 'BUTTER', 'TEA'],
#  ['BUTTER', 'CORNFLAKES', 'TEA', 'COKE', 'ORANGE', 'YOGURT', 'SALT'],
#  ['TEA', 'COKE', 'YOGURT', 'COFFEE', 'MILK', 'BREAD', 'PEPPER', 'EGGS'],
#  ['TEA', 'FLOUR', 'JAM', 'PEPPER'],
#  ['TEA', 'BUTTER', 'YOGURT'],
#  ['COKE', 'COFFEE', 'SUGAR', 'FLOUR', 'MILK', 'PEPPER', 'MAGGI'],
#  ['ORANGE',
#   'PEPPER',
#   'MILK',
#   'COKE',
#   'COFFEE',
#   'MAGGI',
#   'FLOUR',
#   'CORNFLAKES',
#   'TEA'],
#  ['COFFEE', 'COKE', 'JAM', 'SALT', 'FLOUR', 'TEA'],
#  ['CORNFLAKES',
#   'MILK',
#   'TEA',
#   'YOGURT',
#   'MAGGI',
#   'JAM',
#   'EGGS',
#   'PEPPER',
#   'SALT'],
#  ['SALT', 'SUGAR', 'EGGS'],
#  ['SUGAR', 'COFFEE', 'BUTTER', 'YOGURT', 'PEPPER', 'JAM'],
#  ['MAGGI',
#   'TEA',
#   'MILK',
#   'BUTTER',
#   'BREAD',
#   'CORNFLAKES',
#   'FLOUR',
#   'YOGURT',
#   'SALT'],
#  ['FLOUR', 'SALT', 'COKE', 'JAM'],
#  ['RICE', 'JAM', 'BREAD', 'CORNFLAKES', 'YOGURT', 'FLOUR', 'MAGGI', 'BUTTER'],
#  ['YOGURT',
#   'SALT',
#   'TEA',
#   'COFFEE',
#   'RICE',
#   'BREAD',
#   'COKE',
#   'MILK',
#   'MAGGI',
#   'CORNFLAKES'],
#  ['FLOUR',
#   'CORNFLAKES',
#   'MILK',
#   'PEPPER',
#   'MAGGI',
#   'YOGURT',
#   'TEA',
#   'COKE',
#   'BREAD'],
#  ['BREAD', 'MILK', 'PEPPER'],
#  ['RICE', 'ORANGE', 'PEPPER', 'FLOUR'],
#  ['TEA', 'BUTTER', 'MAGGI', 'BREAD', 'CORNFLAKES', 'YOGURT', 'SALT', 'JAM'],
#  ['CORNFLAKES', 'COKE', 'BREAD'],
#  ['ORANGE', 'JAM', 'BREAD'],
#  ['YOGURT', 'COFFEE', 'TEA'],
#  ['FLOUR', 'YOGURT', 'SALT', 'BUTTER', 'JAM'],
#  ['SALT', 'COKE', 'BREAD', 'BUTTER', 'ORANGE', 'CORNFLAKES', 'COFFEE', 'RICE'],
#  ['COKE', 'SALT', 'FLOUR'],
#  ['ORANGE', 'YOGURT', 'COFFEE', 'PEPPER', 'MAGGI'],
#  ['SALT', 'EGGS', 'CORNFLAKES'],
#  ['FLOUR', 'BREAD', 'TEA', 'CORNFLAKES', 'JAM'],
#  ['BUTTER', 'SUGAR', 'COKE', 'COFFEE'],
#  ['COFFEE', 'RICE', 'PEPPER', 'TEA', 'BUTTER', 'BREAD'],
#  ['BREAD', 'PEPPER', 'SUGAR', 'MAGGI', 'JAM', 'YOGURT'],
#  ['BREAD', 'COFFEE', 'BUTTER', 'RICE', 'MILK'],
#  ['MILK', 'COKE', 'EGGS', 'COFFEE', 'FLOUR', 'PEPPER', 'ORANGE', 'MAGGI'],
#  ['MAGGI', 'BUTTER', 'MILK'],
#  ['BREAD',
#   'MAGGI',
#   'YOGURT',
#   'CORNFLAKES',
#   'TEA',
#   'SALT',
#   'MILK',
#   'COKE',
#   'JAM',
#   'BUTTER'],
#  ['FLOUR', 'JAM', 'SUGAR', 'COFFEE'],
#  ['JAM', 'PEPPER', 'YOGURT', 'SUGAR'],
#  ['EGGS',
#   'MILK',
#   'FLOUR',
#   'BUTTER',
#   'TEA',
#   'ORANGE',
#   'SUGAR',
#   'RICE',
#   'BREAD',
#   'COFFEE'],
#  ['MAGGI',
#   'EGGS',
#   'BUTTER',
#   'COKE',
#   'SALT',
#   'SUGAR',
#   'YOGURT',
#   'MILK',
#   'RICE'],
#  ['MILK',
#   'BREAD',
#   'EGGS',
#   'COKE',
#   'SUGAR',
#   'JAM',
#   'COFFEE',
#   'MAGGI',
#   'SALT',
#   'PEPPER'],
#  ['SUGAR', 'EGGS', 'MAGGI', 'RICE', 'JAM', 'FLOUR', 'COKE'],
#  ['MAGGI', 'BREAD', 'COKE'],
#  ['CORNFLAKES', 'MAGGI', 'COKE', 'FLOUR', 'YOGURT'],
#  ['TEA', 'MAGGI', 'SUGAR', 'YOGURT', 'ORANGE', 'MILK'],
#  ['FLOUR', 'CORNFLAKES', 'BUTTER'],
#  ['CORNFLAKES', 'MAGGI', 'SALT', 'TEA'],
#  ['COFFEE',
#   'SALT',
#   'PEPPER',
#   'YOGURT',
#   'BREAD',
#   'COKE',
#   'BUTTER',
#   'SUGAR',
#   'JAM',
#   'TEA'],
#  ['MILK',
#   'MAGGI',
#   'COFFEE',
#   'TEA',
#   'SALT',
#   'JAM',
#   'PEPPER',
#   'ORANGE',
#   'CORNFLAKES'],
#  ['PEPPER', 'SALT', 'CORNFLAKES', 'EGGS', 'BREAD', 'ORANGE', 'JAM', 'FLOUR'],
#  ['TEA', 'COFFEE', 'EGGS', 'MAGGI', 'SALT', 'PEPPER', 'FLOUR', 'BREAD'],
#  ['CORNFLAKES', 'PEPPER', 'MILK', 'BREAD', 'MAGGI', 'RICE'],
#  ['MAGGI',
#   'PEPPER',
#   'BUTTER',
#   'EGGS',
#   'TEA',
#   'SALT',
#   'YOGURT',
#   'COKE',
#   'RICE'],
#  ['SUGAR', 'MAGGI', 'TEA', 'RICE', 'YOGURT', 'SALT', 'PEPPER', 'BREAD'],
#  ['CORNFLAKES', 'COFFEE', 'BUTTER', 'PEPPER', 'FLOUR'],
#  ['ORANGE', 'RICE', 'SALT', 'JAM', 'COKE', 'FLOUR'],
#  ['CORNFLAKES', 'YOGURT', 'MAGGI', 'JAM', 'BREAD', 'FLOUR'],
#  ['BREAD',
#   'FLOUR',
#   'EGGS',
#   'MAGGI',
#   'MILK',
#   'CORNFLAKES',
#   'ORANGE',
#   'COFFEE',
#   'PEPPER'],
#  ['ORANGE', 'FLOUR', 'JAM', 'YOGURT', 'MILK', 'COFFEE', 'CORNFLAKES', 'MAGGI'],
#  ['PEPPER', 'ORANGE', 'BUTTER', 'MAGGI'],
#  ['BREAD', 'RICE', 'BUTTER'],
#  ['RICE', 'FLOUR', 'COFFEE', 'ORANGE', 'PEPPER'],
#  ['SUGAR',
#   'MAGGI',
#   'JAM',
#   'MILK',
#   'SALT',
#   'FLOUR',
#   'COFFEE',
#   'TEA',
#   'EGGS',
#   'COKE'],
#  ['ORANGE', 'CORNFLAKES', 'SALT', 'COKE', 'YOGURT', 'TEA', 'MAGGI'],
#  ['CORNFLAKES',
#   'BUTTER',
#   'JAM',
#   'TEA',
#   'RICE',
#   'BREAD',
#   'FLOUR',
#   'SUGAR',
#   'PEPPER'],
#  ['FLOUR', 'BUTTER', 'TEA', 'SUGAR'],
#  ['PEPPER', 'BUTTER', 'MAGGI', 'EGGS', 'RICE'],
#  ['MILK', 'BREAD', 'FLOUR', 'SUGAR', 'ORANGE', 'YOGURT'],
#  ['PEPPER', 'SALT', 'RICE', 'MILK', 'ORANGE'],
#  ['FLOUR', 'MAGGI', 'PEPPER'],
#  ['BREAD', 'MAGGI', 'CORNFLAKES'],
#  ['BUTTER', 'ORANGE', 'TEA', 'EGGS', 'BREAD', 'COFFEE', 'MAGGI', 'JAM'],
#  ['EGGS', 'MILK', 'BUTTER', 'BREAD'],
#  ['MILK',
#   'BREAD',
#   'COFFEE',
#   'RICE',
#   'COKE',
#   'BUTTER',
#   'PEPPER',
#   'CORNFLAKES',
#   'JAM'],
#  ['CORNFLAKES', 'MAGGI', 'COKE', 'BUTTER', 'RICE', 'FLOUR'],
#  ['COFFEE', 'FLOUR', 'PEPPER'],
#  ['CORNFLAKES', 'PEPPER', 'ORANGE', 'TEA', 'SUGAR'],
#  ['YOGURT', 'MILK', 'ORANGE'],
#  ['SALT', 'TEA', 'EGGS', 'BREAD', 'CORNFLAKES', 'BUTTER'],
#  ['COKE', 'EGGS', 'RICE', 'SALT', 'BUTTER'],
#  ['EGGS',
#   'ORANGE',
#   'MILK',
#   'CORNFLAKES',
#   'SALT',
#   'MAGGI',
#   'COKE',
#   'RICE',
#   'JAM'],
#  ['COFFEE', 'SUGAR', 'COKE', 'MILK'],
#  ['FLOUR', 'SALT', 'BREAD', 'ORANGE', 'COKE'],
#  ['EGGS', 'CORNFLAKES', 'TEA', 'PEPPER', 'RICE', 'BUTTER'],
#  ['BREAD', 'EGGS', 'RICE', 'MILK', 'JAM', 'SUGAR'],
#  ['CORNFLAKES', 'SALT', 'COKE', 'ORANGE'],
#  ['SALT', 'COKE', 'MILK', 'FLOUR', 'MAGGI', 'CORNFLAKES', 'BREAD', 'BUTTER'],
#  ['FLOUR', 'COKE', 'ORANGE', 'YOGURT'],
#  ['SUGAR',
#   'BREAD',
#   'COFFEE',
#   'RICE',
#   'TEA',
#   'BUTTER',
#   'ORANGE',
#   'FLOUR',
#   'JAM'],
#  ['TEA', 'EGGS', 'SALT', 'BREAD', 'BUTTER'],
#  ['EGGS', 'JAM', 'COKE', 'FLOUR'],
#  ['SALT',
#   'BUTTER',
#   'SUGAR',
#   'COFFEE',
#   'RICE',
#   'CORNFLAKES',
#   'ORANGE',
#   'BREAD',
#   'EGGS'],
#  ['CORNFLAKES',
#   'COKE',
#   'SALT',
#   'COFFEE',
#   'BUTTER',
#   'EGGS',
#   'FLOUR',
#   'YOGURT',
#   'ORANGE',
#   'BREAD'],
#  ['FLOUR',
#   'CORNFLAKES',
#   'PEPPER',
#   'RICE',
#   'JAM',
#   'BUTTER',
#   'YOGURT',
#   'COFFEE',
#   'MAGGI'],
#  ['ORANGE', 'BREAD', 'SUGAR', 'RICE', 'FLOUR', 'COFFEE', 'PEPPER'],
#  ['JAM', 'COKE', 'MILK', 'PEPPER', 'BREAD'],
#  ['COFFEE',
#   'EGGS',
#   'BREAD',
#   'FLOUR',
#   'BUTTER',
#   'SALT',
#   'COKE',
#   'ORANGE',
#   'SUGAR',
#   'CORNFLAKES'],
#  ['BUTTER', 'YOGURT', 'EGGS', 'MAGGI', 'TEA', 'ORANGE', 'JAM'],
#  ['BREAD', 'PEPPER', 'JAM'],
#  ['SALT', 'SUGAR', 'COFFEE'],
#  ['FLOUR', 'MAGGI', 'COFFEE', 'YOGURT'],
#  ['BREAD',
#   'MILK',
#   'EGGS',
#   'BUTTER',
#   'TEA',
#   'COKE',
#   'SUGAR',
#   'FLOUR',
#   'CORNFLAKES',
#   'ORANGE'],
#  ['COFFEE', 'RICE', 'YOGURT', 'ORANGE', 'MILK', 'MAGGI', 'PEPPER', 'EGGS'],
#  ['COFFEE', 'SUGAR', 'SALT', 'TEA', 'BUTTER', 'MAGGI'],
#  ['SUGAR', 'BUTTER', 'MAGGI', 'JAM', 'COFFEE', 'EGGS', 'ORANGE'],
#  ['TEA', 'RICE', 'SUGAR', 'ORANGE', 'COKE', 'COFFEE'],
#  ['CORNFLAKES', 'MILK', 'TEA', 'BREAD'],
#  ['TEA',
#   'EGGS',
#   'MILK',
#   'MAGGI',
#   'SUGAR',
#   'BUTTER',
#   'JAM',
#   'PEPPER',
#   'ORANGE',
#   'FLOUR'],
#  ['CORNFLAKES', 'BREAD', 'EGGS'],
#  ['CORNFLAKES', 'TEA', 'PEPPER', 'BREAD', 'COKE'],
#  ['SALT', 'FLOUR', 'SUGAR', 'EGGS', 'COFFEE', 'ORANGE', 'JAM', 'MILK'],
#  ['COKE', 'ORANGE', 'TEA', 'MAGGI', 'FLOUR', 'MILK', 'SUGAR', 'PEPPER', 'JAM'],
#  ['COKE', 'CORNFLAKES', 'BUTTER', 'SUGAR'],
#  ['PEPPER', 'MILK', 'BUTTER', 'RICE', 'FLOUR', 'COKE'],
#  ['PEPPER', 'ORANGE', 'RICE', 'TEA', 'BREAD', 'MAGGI', 'JAM'],
#  ['BREAD', 'TEA', 'SUGAR', 'SALT', 'RICE', 'MILK', 'COKE', 'COFFEE', 'MAGGI'],
#  ['COFFEE',
#   'COKE',
#   'CORNFLAKES',
#   'MAGGI',
#   'JAM',
#   'BREAD',
#   'PEPPER',
#   'SALT',
#   'MILK',
#   'FLOUR'],
#  ['SUGAR', 'PEPPER', 'ORANGE', 'MILK', 'COKE'],
#  ['YOGURT', 'MAGGI', 'COFFEE', 'SALT', 'JAM'],
#  ['ORANGE', 'YOGURT', 'BUTTER', 'BREAD'],
#  ['COKE',
#   'JAM',
#   'RICE',
#   'ORANGE',
#   'SALT',
#   'CORNFLAKES',
#   'MILK',
#   'BREAD',
#   'FLOUR',
#   'PEPPER'],
#  ['TEA', 'MILK', 'MAGGI', 'RICE', 'EGGS', 'JAM'],
#  ['EGGS', 'MILK', 'JAM', 'BREAD', 'BUTTER', 'MAGGI', 'COKE'],
#  ['COKE', 'BUTTER', 'FLOUR'],
#  ['BUTTER', 'PEPPER', 'YOGURT'],
#  ['EGGS', 'YOGURT', 'MILK', 'PEPPER'],
#  ['SALT', 'FLOUR', 'RICE'],
#  ['RICE', 'COKE', 'EGGS', 'BUTTER', 'MILK'],
#  ['COFFEE',
#   'SUGAR',
#   'BUTTER',
#   'EGGS',
#   'FLOUR',
#   'SALT',
#   'COKE',
#   'JAM',
#   'CORNFLAKES'],
#  ['MAGGI', 'COKE', 'TEA', 'BREAD'],
#  ['PEPPER', 'TEA', 'RICE', 'EGGS', 'CORNFLAKES', 'BREAD', 'SALT', 'MAGGI'],
#  ['FLOUR', 'MILK', 'COFFEE', 'EGGS', 'YOGURT', 'TEA', 'CORNFLAKES'],
#  ['CORNFLAKES', 'BUTTER', 'COKE', 'EGGS', 'BREAD', 'MILK'],
#  ['RICE',
#   'SUGAR',
#   'COFFEE',
#   'YOGURT',
#   'ORANGE',
#   'JAM',
#   'FLOUR',
#   'BREAD',
#   'EGGS'],
#  ['COFFEE', 'EGGS', 'SUGAR'],
#  ['MILK', 'BREAD', 'PEPPER'],
#  ['COKE', 'RICE', 'JAM', 'SALT', 'EGGS', 'CORNFLAKES', 'FLOUR', 'MAGGI'],
#  ['MILK', 'RICE', 'ORANGE', 'JAM', 'MAGGI', 'COKE'],
#  ['MAGGI', 'BREAD', 'ORANGE', 'TEA', 'BUTTER', 'MILK', 'SUGAR', 'PEPPER'],
#  ['COFFEE', 'JAM', 'TEA', 'MILK', 'SALT'],
#  ['CORNFLAKES',
#   'PEPPER',
#   'JAM',
#   'YOGURT',
#   'RICE',
#   'FLOUR',
#   'COKE',
#   'ORANGE',
#   'SALT'],
#  ['RICE', 'SUGAR', 'COFFEE', 'EGGS'],
#  ['ORANGE', 'JAM', 'EGGS', 'RICE', 'SUGAR', 'BREAD'],
#  ['COKE', 'YOGURT', 'EGGS', 'PEPPER', 'BUTTER'],
#  ['YOGURT', 'JAM', 'FLOUR', 'MILK', 'SUGAR', 'COKE', 'ORANGE'],
#  ['JAM', 'RICE', 'MAGGI', 'SUGAR'],
#  ['SALT', 'MILK', 'COFFEE'],
#  ['SALT', 'YOGURT', 'MAGGI', 'PEPPER', 'ORANGE', 'FLOUR', 'BUTTER', 'TEA'],
#  ['JAM', 'MAGGI', 'FLOUR', 'ORANGE', 'SALT'],
#  ['COKE', 'TEA', 'MAGGI', 'YOGURT', 'COFFEE', 'BUTTER', 'SUGAR'],
#  ['EGGS', 'BUTTER', 'COKE', 'PEPPER'],
#  ['YOGURT', 'ORANGE', 'TEA', 'FLOUR', 'SUGAR'],
#  ['BREAD', 'TEA', 'YOGURT', 'MILK', 'JAM'],
#  ['BREAD', 'RICE', 'EGGS', 'YOGURT'],
#  ['FLOUR', 'MILK', 'BUTTER'],
#  ['PEPPER',
#   'MILK',
#   'YOGURT',
#   'CORNFLAKES',
#   'SALT',
#   'ORANGE',
#   'JAM',
#   'RICE',
#   'COKE'],
#  ['ORANGE', 'EGGS', 'YOGURT', 'FLOUR', 'TEA', 'SUGAR'],
#  ['BUTTER', 'JAM', 'EGGS', 'ORANGE', 'SUGAR', 'MAGGI', 'TEA', 'BREAD', 'RICE'],
#  ['MAGGI', 'JAM', 'RICE', 'SUGAR', 'PEPPER', 'FLOUR'],
#  ['RICE',
#   'BREAD',
#   'ORANGE',
#   'CORNFLAKES',
#   'PEPPER',
#   'BUTTER',
#   'TEA',
#   'EGGS',
#   'FLOUR',
#   'MILK'],
#  ['COKE', 'MAGGI', 'CORNFLAKES', 'COFFEE', 'BUTTER', 'ORANGE'],
#  ['CORNFLAKES',
#   'COFFEE',
#   'MILK',
#   'RICE',
#   'YOGURT',
#   'COKE',
#   'PEPPER',
#   'BREAD',
#   'FLOUR'],
#  ['MILK',
#   'FLOUR',
#   'COFFEE',
#   'PEPPER',
#   'TEA',
#   'COKE',
#   'YOGURT',
#   'CORNFLAKES',
#   'JAM'],
#  ['SUGAR', 'PEPPER', 'RICE', 'BUTTER', 'BREAD', 'CORNFLAKES'],
#  ['EGGS', 'MAGGI', 'SALT', 'COFFEE', 'ORANGE', 'BUTTER', 'PEPPER'],
#  ['BREAD', 'BUTTER', 'MAGGI'],
#  ['SUGAR',
#   'COKE',
#   'YOGURT',
#   'JAM',
#   'SALT',
#   'COFFEE',
#   'BUTTER',
#   'MAGGI',
#   'TEA'],
#  ['ORANGE', 'SALT', 'FLOUR', 'COFFEE', 'SUGAR', 'EGGS', 'TEA', 'YOGURT'],
#  ['BREAD', 'MILK', 'RICE', 'BUTTER', 'SUGAR', 'ORANGE', 'YOGURT', 'EGGS'],
#  ['TEA',
#   'SALT',
#   'ORANGE',
#   'MAGGI',
#   'SUGAR',
#   'COFFEE',
#   'BREAD',
#   'RICE',
#   'EGGS',
#   'COKE'],
#  ['CORNFLAKES', 'BREAD', 'SUGAR', 'BUTTER'],
#  ['EGGS', 'SUGAR', 'PEPPER', 'BUTTER', 'FLOUR', 'TEA'],
#  ['FLOUR',
#   'BREAD',
#   'EGGS',
#   'BUTTER',
#   'JAM',
#   'PEPPER',
#   'RICE',
#   'MILK',
#   'ORANGE',
#   'SUGAR'],
#  ['BREAD', 'FLOUR', 'ORANGE', 'MAGGI', 'TEA', 'SUGAR'],
#  ['BUTTER',
#   'TEA',
#   'SUGAR',
#   'SALT',
#   'CORNFLAKES',
#   'FLOUR',
#   'BREAD',
#   'EGGS',
#   'YOGURT'],
#  ['PEPPER', 'FLOUR', 'BUTTER', 'EGGS', 'TEA', 'BREAD'],
#  ['TEA', 'SALT', 'CORNFLAKES', 'MAGGI', 'RICE'],
#  ['SALT', 'MAGGI', 'YOGURT'],
#  ['RICE', 'PEPPER', 'SALT', 'COKE', 'EGGS'],
#  ['COFFEE', 'BUTTER', 'SALT', 'BREAD', 'MAGGI', 'CORNFLAKES'],
#  ['FLOUR', 'CORNFLAKES', 'COFFEE', 'ORANGE', 'MILK', 'COKE', 'TEA', 'JAM'],
#  ['COFFEE', 'RICE', 'FLOUR', 'MILK', 'JAM'],
#  ['SALT', 'MAGGI', 'RICE', 'COKE', 'TEA', 'YOGURT'],
#  ['SUGAR',
#   'CORNFLAKES',
#   'COFFEE',
#   'MILK',
#   'YOGURT',
#   'PEPPER',
#   'RICE',
#   'FLOUR',
#   'SALT'],
#  ['MAGGI', 'RICE', 'TEA', 'ORANGE', 'BUTTER', 'SUGAR', 'MILK', 'CORNFLAKES'],
#  ['YOGURT', 'TEA', 'MILK'],
#  ['SUGAR', 'EGGS', 'JAM', 'SALT', 'MILK', 'RICE', 'BUTTER'],
#  ['JAM', 'BUTTER', 'TEA', 'MILK', 'COFFEE', 'MAGGI', 'SALT'],
#  ['EGGS', 'BREAD', 'JAM', 'BUTTER', 'TEA', 'SUGAR'],
#  ['PEPPER', 'TEA', 'SUGAR', 'CORNFLAKES', 'BUTTER'],
#  ['EGGS', 'YOGURT', 'JAM', 'BREAD', 'MAGGI'],
#  ['BUTTER', 'COFFEE', 'ORANGE', 'MILK'],
#  ['JAM', 'YOGURT', 'MILK'],
#  ['COKE',
#   'EGGS',
#   'CORNFLAKES',
#   'FLOUR',
#   'ORANGE',
#   'YOGURT',
#   'COFFEE',
#   'SALT',
#   'TEA',
#   'MAGGI'],
#  ['SALT', 'PEPPER', 'MAGGI', 'MILK', 'BREAD', 'COFFEE', 'FLOUR'],
#  ['RICE', 'EGGS', 'JAM'],
#  ['COKE', 'PEPPER', 'RICE', 'SUGAR'],
#  ['FLOUR',
#   'BUTTER',
#   'COKE',
#   'SUGAR',
#   'MILK',
#   'CORNFLAKES',
#   'SALT',
#   'COFFEE',
#   'RICE',
#   'EGGS'],
#  ['COKE', 'BUTTER', 'FLOUR', 'COFFEE', 'CORNFLAKES'],
#  ['BUTTER', 'COKE', 'CORNFLAKES', 'BREAD', 'MILK', 'COFFEE'],
#  ['PEPPER', 'EGGS', 'SALT', 'YOGURT', 'COKE', 'SUGAR'],
#  ['BREAD', 'ORANGE', 'SUGAR', 'BUTTER', 'MILK', 'EGGS'],
#  ['COKE',
#   'SUGAR',
#   'BUTTER',
#   'MILK',
#   'COFFEE',
#   'BREAD',
#   'FLOUR',
#   'SALT',
#   'YOGURT',
#   'TEA'],
#  ['PEPPER',
#   'ORANGE',
#   'JAM',
#   'YOGURT',
#   'SALT',
#   'MILK',
#   'TEA',
#   'FLOUR',
#   'SUGAR'],
#  ['ORANGE', 'MAGGI', 'RICE', 'YOGURT', 'BREAD', 'FLOUR', 'TEA', 'BUTTER'],
#  ['EGGS', 'COFFEE', 'COKE', 'RICE', 'MILK'],
#  ['YOGURT', 'RICE', 'PEPPER'],
#  ['TEA', 'MAGGI', 'EGGS', 'JAM', 'FLOUR', 'CORNFLAKES', 'PEPPER', 'ORANGE'],
#  ['SALT',
#   'MAGGI',
#   'BUTTER',
#   'CORNFLAKES',
#   'TEA',
#   'JAM',
#   'MILK',
#   'SUGAR',
#   'ORANGE'],
#  ['BREAD', 'RICE', 'SUGAR'],
#  ['RICE', 'SALT', 'PEPPER', 'ORANGE'],
#  ['JAM', 'YOGURT', 'ORANGE', 'MAGGI', 'EGGS', 'BUTTER', 'RICE', 'COFFEE'],
#  ['BUTTER', 'BREAD', 'PEPPER', 'COKE', 'SUGAR'],
#  ['CORNFLAKES', 'COFFEE', 'COKE', 'SUGAR', 'TEA', 'ORANGE', 'MAGGI', 'RICE'],
#  ['BUTTER', 'RICE', 'EGGS', 'JAM'],
#  ['FLOUR', 'JAM', 'BREAD'],
#  ['BREAD', 'SUGAR', 'COKE', 'CORNFLAKES', 'ORANGE', 'JAM'],
#  ['SUGAR', 'BUTTER', 'TEA', 'YOGURT', 'SALT', 'COFFEE', 'JAM'],
#  ['TEA',
#   'PEPPER',
#   'CORNFLAKES',
#   'ORANGE',
#   'MAGGI',
#   'FLOUR',
#   'RICE',
#   'COFFEE',
#   'BREAD'],
#  ['SUGAR',
#   'RICE',
#   'SALT',
#   'MILK',
#   'TEA',
#   'FLOUR',
#   'JAM',
#   'PEPPER',
#   'YOGURT',
#   'CORNFLAKES'],
#  ['JAM',
#   'YOGURT',
#   'SALT',
#   'ORANGE',
#   'MAGGI',
#   'FLOUR',
#   'BREAD',
#   'EGGS',
#   'BUTTER'],
#  ['EGGS', 'BUTTER', 'RICE', 'FLOUR', 'MILK', 'SUGAR'],
#  ['BUTTER',
#   'BREAD',
#   'PEPPER',
#   'MAGGI',
#   'TEA',
#   'JAM',
#   'EGGS',
#   'COFFEE',
#   'RICE',
#   'SALT'],
#  ['SALT', 'MAGGI', 'MILK', 'EGGS', 'YOGURT'],
#  ['CORNFLAKES', 'COKE', 'COFFEE', 'BREAD', 'FLOUR'],
#  ['COKE', 'BREAD', 'EGGS', 'FLOUR', 'PEPPER', 'CORNFLAKES', 'COFFEE'],
#  ['FLOUR', 'CORNFLAKES', 'PEPPER', 'SUGAR', 'RICE', 'TEA', 'BREAD'],
#  ['MAGGI', 'SUGAR', 'EGGS', 'CORNFLAKES', 'BREAD'],
#  ['PEPPER', 'ORANGE', 'COKE', 'BUTTER', 'MILK', 'TEA', 'CORNFLAKES'],
#  ['MILK', 'PEPPER', 'TEA', 'BUTTER', 'SUGAR', 'COFFEE'],
#  ['JAM',
#   'SALT',
#   'YOGURT',
#   'BREAD',
#   'CORNFLAKES',
#   'PEPPER',
#   'COKE',
#   'SUGAR',
#   'ORANGE'],
#  ['TEA', 'RICE', 'SALT'],
#  ['PEPPER', 'BREAD', 'EGGS', 'MILK', 'CORNFLAKES', 'SALT'],
#  ['MAGGI', 'RICE', 'SALT', 'COFFEE', 'BREAD', 'BUTTER'],
#  ['BUTTER', 'MILK', 'COKE'],
#  ['COKE',
#   'SALT',
#   'CORNFLAKES',
#   'YOGURT',
#   'PEPPER',
#   'TEA',
#   'BREAD',
#   'MAGGI',
#   'MILK',
#   'COFFEE'],
#  ['BREAD',
#   'BUTTER',
#   'MAGGI',
#   'EGGS',
#   'JAM',
#   'ORANGE',
#   'YOGURT',
#   'COKE',
#   'SALT',
#   'PEPPER'],
#  ['MAGGI', 'RICE', 'COKE'],
#  ['SUGAR', 'COFFEE', 'FLOUR'],
#  ['ORANGE', 'MILK', 'YOGURT'],
#  ['EGGS', 'PEPPER', 'TEA', 'RICE', 'CORNFLAKES'],
#  ['FLOUR', 'YOGURT', 'COFFEE', 'SUGAR', 'MILK', 'TEA', 'ORANGE'],
#  ['MILK', 'PEPPER', 'SUGAR', 'ORANGE'],
#  ['PEPPER',
#   'YOGURT',
#   'COKE',
#   'JAM',
#   'CORNFLAKES',
#   'ORANGE',
#   'BREAD',
#   'RICE',
#   'SUGAR',
#   'MAGGI'],
#  ['BUTTER', 'COKE', 'COFFEE', 'TEA', 'YOGURT', 'BREAD'],
#  ['COFFEE',
#   'TEA',
#   'BREAD',
#   'ORANGE',
#   'YOGURT',
#   'FLOUR',
#   'SUGAR',
#   'JAM',
#   'PEPPER'],
#  ['SUGAR', 'PEPPER', 'MAGGI', 'CORNFLAKES', 'BREAD', 'YOGURT', 'COKE'],
#  ['PEPPER', 'MILK', 'COKE', 'FLOUR', 'BREAD', 'BUTTER', 'TEA'],
#  ['BREAD', 'ORANGE', 'SALT', 'JAM', 'YOGURT', 'BUTTER', 'FLOUR', 'RICE'],
#  ['BUTTER',
#   'CORNFLAKES',
#   'COFFEE',
#   'TEA',
#   'YOGURT',
#   'BREAD',
#   'FLOUR',
#   'SUGAR',
#   'SALT'],
#  ['BREAD',
#   'YOGURT',
#   'COFFEE',
#   'PEPPER',
#   'TEA',
#   'ORANGE',
#   'BUTTER',
#   'COKE',
#   'JAM'],
#  ['SALT', 'BREAD', 'SUGAR'],
#  ['SUGAR',
#   'SALT',
#   'JAM',
#   'BREAD',
#   'PEPPER',
#   'EGGS',
#   'COFFEE',
#   'RICE',
#   'YOGURT',
#   'MAGGI'],
#  ['BUTTER', 'COKE', 'YOGURT', 'TEA', 'SUGAR', 'PEPPER'],
#  ['RICE', 'MAGGI', 'SALT', 'COFFEE', 'BUTTER', 'EGGS', 'COKE'],
#  ['RICE', 'CORNFLAKES', 'MAGGI', 'ORANGE', 'PEPPER', 'BREAD'],
#  ['SALT', 'PEPPER', 'CORNFLAKES', 'COKE', 'FLOUR', 'BREAD', 'TEA'],
#  ['YOGURT', 'MAGGI', 'BUTTER', 'COKE'],
#  ['MAGGI',
#   'TEA',
#   'SUGAR',
#   'MILK',
#   'BUTTER',
#   'EGGS',
#   'CORNFLAKES',
#   'YOGURT',
#   'PEPPER'],
#  ['MILK', 'CORNFLAKES', 'YOGURT', 'EGGS', 'BREAD', 'SALT', 'MAGGI'],
#  ['JAM', 'PEPPER', 'TEA', 'RICE'],
#  ['JAM',
#   'TEA',
#   'BREAD',
#   'CORNFLAKES',
#   'COFFEE',
#   'COKE',
#   'YOGURT',
#   'BUTTER',
#   'MAGGI'],
#  ['YOGURT', 'MAGGI', 'CORNFLAKES', 'TEA', 'BREAD', 'PEPPER'],
#  ['MAGGI', 'BREAD', 'RICE', 'YOGURT'],
#  ['PEPPER',
#   'RICE',
#   'JAM',
#   'YOGURT',
#   'SALT',
#   'FLOUR',
#   'MAGGI',
#   'EGGS',
#   'ORANGE'],
#  ['CORNFLAKES',
#   'COFFEE',
#   'ORANGE',
#   'PEPPER',
#   'BREAD',
#   'TEA',
#   'EGGS',
#   'FLOUR',
#   'MILK'],
#  ['MAGGI',
#   'SUGAR',
#   'JAM',
#   'MILK',
#   'EGGS',
#   'ORANGE',
#   'TEA',
#   'CORNFLAKES',
#   'FLOUR',
#   'COKE'],
#  ['SALT', 'BUTTER', 'BREAD', 'SUGAR', 'ORANGE'],
#  ['MAGGI',
#   'YOGURT',
#   'EGGS',
#   'TEA',
#   'COFFEE',
#   'CORNFLAKES',
#   'ORANGE',
#   'SUGAR',
#   'FLOUR'],
#  ['MILK', 'TEA', 'RICE', 'JAM'],
#  ['YOGURT', 'EGGS', 'MAGGI', 'COKE', 'PEPPER', 'JAM', 'MILK'],
#  ['SALT', 'MAGGI', 'TEA', 'COKE', 'BUTTER', 'MILK', 'RICE', 'ORANGE', 'EGGS'],
#  ['MILK', 'BREAD', 'ORANGE', 'RICE', 'FLOUR', 'MAGGI', 'SALT'],
#  ['COKE', 'MAGGI', 'CORNFLAKES', 'JAM', 'BREAD', 'RICE'],
#  ['YOGURT', 'MILK', 'FLOUR', 'TEA', 'SUGAR', 'SALT', 'MAGGI'],
#  ['BREAD', 'FLOUR', 'PEPPER', 'TEA', 'BUTTER', 'YOGURT', 'COKE'],
#  ['COKE', 'MILK', 'JAM', 'PEPPER', 'BREAD', 'TEA', 'ORANGE'],
#  ['MAGGI',
#   'JAM',
#   'FLOUR',
#   'BUTTER',
#   'RICE',
#   'SUGAR',
#   'ORANGE',
#   'BREAD',
#   'COFFEE',
#   'EGGS'],
#  ['TEA',
#   'COKE',
#   'YOGURT',
#   'SALT',
#   'MAGGI',
#   'BREAD',
#   'FLOUR',
#   'JAM',
#   'PEPPER',
#   'CORNFLAKES'],
#  ['TEA', 'JAM', 'BUTTER', 'RICE', 'SALT', 'ORANGE', 'COKE', 'MILK', 'BREAD'],
#  ['YOGURT',
#   'RICE',
#   'PEPPER',
#   'MILK',
#   'BREAD',
#   'EGGS',
#   'TEA',
#   'FLOUR',
#   'JAM',
#   'CORNFLAKES'],
#  ['BREAD', 'EGGS', 'BUTTER', 'COKE'],
#  ['EGGS', 'MAGGI', 'SALT'],
#  ['JAM',
#   'PEPPER',
#   'BREAD',
#   'SUGAR',
#   'FLOUR',
#   'EGGS',
#   'TEA',
#   'COFFEE',
#   'CORNFLAKES'],
#  ['JAM',
#   'ORANGE',
#   'CORNFLAKES',
#   'MILK',
#   'YOGURT',
#   'BREAD',
#   'BUTTER',
#   'EGGS',
#   'SUGAR',
#   'TEA'],
#  ['FLOUR', 'BUTTER', 'PEPPER', 'SUGAR', 'BREAD', 'SALT', 'COKE', 'MAGGI'],
#  ['MILK', 'JAM', 'ORANGE', 'COFFEE', 'BREAD'],
#  ['SALT', 'EGGS', 'BREAD', 'ORANGE', 'YOGURT', 'CORNFLAKES', 'RICE'],
#  ['COKE', 'RICE', 'BREAD', 'FLOUR', 'TEA'],
#  ['EGGS', 'BREAD', 'JAM'],
#  ['ORANGE', 'JAM', 'COFFEE', 'SUGAR', 'EGGS', 'BUTTER', 'COKE'],
#  ['BREAD', 'COFFEE', 'BUTTER'],
#  ['CORNFLAKES', 'TEA', 'COKE', 'EGGS', 'MILK', 'PEPPER', 'ORANGE', 'YOGURT'],
#  ['RICE', 'CORNFLAKES', 'MAGGI', 'SUGAR', 'TEA', 'SALT'],
#  ['SUGAR',
#   'MAGGI',
#   'CORNFLAKES',
#   'YOGURT',
#   'SALT',
#   'COFFEE',
#   'ORANGE',
#   'TEA',
#   'MILK'],
#  ['COKE', 'BUTTER', 'EGGS', 'CORNFLAKES', 'MILK'],
#  ['RICE', 'FLOUR', 'MAGGI', 'COKE'],
#  ['SALT', 'BREAD', 'COKE', 'MAGGI', 'YOGURT', 'PEPPER'],
#  ['BUTTER',
#   'MAGGI',
#   'BREAD',
#   'MILK',
#   'TEA',
#   'CORNFLAKES',
#   'SALT',
#   'YOGURT',
#   'FLOUR',
#   'JAM'],
#  ['EGGS', 'CORNFLAKES', 'YOGURT', 'RICE', 'FLOUR', 'BREAD', 'JAM'],
#  ['BUTTER', 'COFFEE', 'PEPPER', 'TEA', 'MAGGI'],
#  ['MILK', 'RICE', 'MAGGI', 'SALT', 'PEPPER'],
#  ['TEA', 'BUTTER', 'ORANGE', 'EGGS', 'MAGGI', 'COKE', 'BREAD'],
#  ['COKE',
#   'ORANGE',
#   'MILK',
#   'JAM',
#   'FLOUR',
#   'SUGAR',
#   'EGGS',
#   'CORNFLAKES',
#   'RICE',
#   'YOGURT'],
#  ['PEPPER', 'BREAD', 'SALT'],
#  ['MILK', 'TEA', 'FLOUR', 'YOGURT', 'SALT', 'PEPPER'],
#  ['EGGS', 'ORANGE', 'COFFEE', 'YOGURT', 'FLOUR'],
#  ['RICE', 'ORANGE', 'YOGURT'],
#  ['EGGS',
#   'RICE',
#   'MILK',
#   'MAGGI',
#   'COKE',
#   'ORANGE',
#   'TEA',
#   'COFFEE',
#   'BREAD',
#   'JAM'],
#  ['MAGGI',
#   'BUTTER',
#   'FLOUR',
#   'JAM',
#   'COKE',
#   'BREAD',
#   'SALT',
#   'RICE',
#   'COFFEE'],
#  ['PEPPER',
#   'JAM',
#   'CORNFLAKES',
#   'TEA',
#   'ORANGE',
#   'COKE',
#   'BREAD',
#   'MAGGI',
#   'FLOUR',
#   'MILK'],
#  ['TEA', 'FLOUR', 'COKE', 'YOGURT', 'ORANGE', 'COFFEE'],
#  ['BREAD',
#   'JAM',
#   'BUTTER',
#   'MAGGI',
#   'COKE',
#   'RICE',
#   'ORANGE',
#   'PEPPER',
#   'CORNFLAKES'],
#  ['BUTTER',
#   'BREAD',
#   'YOGURT',
#   'JAM',
#   'SALT',
#   'TEA',
#   'ORANGE',
#   'PEPPER',
#   'CORNFLAKES',
#   'EGGS'],
#  ['MILK', 'PEPPER', 'EGGS', 'CORNFLAKES', 'COKE', 'MAGGI'],
#  ['SUGAR', 'BUTTER', 'ORANGE', 'JAM', 'YOGURT'],
#  ['SUGAR', 'TEA', 'COKE', 'MILK', 'COFFEE', 'FLOUR', 'SALT', 'YOGURT'],
#  ['MAGGI', 'BUTTER', 'FLOUR', 'COKE', 'SALT', 'CORNFLAKES'],
#  ['SALT', 'CORNFLAKES', 'MILK', 'RICE'],
#  ['PEPPER', 'YOGURT', 'CORNFLAKES', 'ORANGE', 'RICE'],
#  ['SUGAR',
#   'FLOUR',
#   'BREAD',
#   'CORNFLAKES',
#   'EGGS',
#   'BUTTER',
#   'YOGURT',
#   'RICE',
#   'ORANGE',
#   'MAGGI'],
#  ['MILK', 'TEA', 'SUGAR'],
#  ['MILK', 'COKE', 'BUTTER', 'YOGURT', 'SALT'],
#  ['MILK', 'YOGURT', 'EGGS', 'JAM', 'PEPPER', 'SALT'],
#  ['FLOUR', 'RICE', 'MILK', 'PEPPER', 'BREAD'],
#  ['CORNFLAKES', 'SALT', 'COFFEE'],
#  ['ORANGE', 'CORNFLAKES', 'JAM', 'COKE', 'MAGGI', 'BUTTER'],
#  ['FLOUR', 'CORNFLAKES', 'TEA'],
#  ['RICE',
#   'SALT',
#   'MILK',
#   'PEPPER',
#   'COFFEE',
#   'EGGS',
#   'FLOUR',
#   'COKE',
#   'BREAD',
#   'TEA'],
#  ['COFFEE',
#   'FLOUR',
#   'MAGGI',
#   'COKE',
#   'TEA',
#   'BREAD',
#   'ORANGE',
#   'PEPPER',
#   'BUTTER',
#   'SALT'],
#  ['MAGGI', 'MILK', 'ORANGE', 'CORNFLAKES'],
#  ['SALT', 'MAGGI', 'ORANGE', 'PEPPER', 'EGGS', 'CORNFLAKES'],
#  ['JAM',
#   'MAGGI',
#   'FLOUR',
#   'BREAD',
#   'COFFEE',
#   'ORANGE',
#   'TEA',
#   'CORNFLAKES',
#   'YOGURT'],
#  ['MAGGI', 'SUGAR', 'BREAD', 'JAM', 'COKE', 'FLOUR', 'TEA', 'RICE'],
#  ['JAM', 'SUGAR', 'YOGURT', 'FLOUR', 'SALT', 'COKE', 'TEA', 'COFFEE'],
#  ['EGGS',
#   'BUTTER',
#   'RICE',
#   'COKE',
#   'MAGGI',
#   'CORNFLAKES',
#   'COFFEE',
#   'PEPPER',
#   'MILK',
#   'SALT'],
#  ['JAM', 'MILK', 'FLOUR', 'BREAD', 'MAGGI', 'SUGAR', 'CORNFLAKES', 'RICE'],
#  ['MILK', 'PEPPER', 'YOGURT', 'TEA', 'BUTTER', 'COFFEE'],
#  ['PEPPER', 'SUGAR', 'BREAD', 'EGGS', 'MILK', 'RICE', 'YOGURT'],
#  ['PEPPER', 'EGGS', 'COKE', 'ORANGE', 'SALT', 'BUTTER', 'BREAD', 'SUGAR'],
#  ['ORANGE', 'RICE', 'FLOUR', 'MILK', 'TEA', 'COFFEE', 'YOGURT'],
#  ['MILK', 'FLOUR', 'EGGS', 'SALT'],
#  ['ORANGE',
#   'SUGAR',
#   'BUTTER',
#   'COKE',
#   'RICE',
#   'BREAD',
#   'TEA',
#   'PEPPER',
#   'COFFEE'],
#  ['BREAD', 'PEPPER', 'ORANGE'],
#  ['SUGAR', 'RICE', 'PEPPER'],
#  ['EGGS', 'COFFEE', 'RICE', 'BREAD'],
#  ['CORNFLAKES', 'YOGURT', 'MILK', 'SALT'],
#  ['BUTTER', 'COKE', 'TEA', 'COFFEE', 'JAM', 'ORANGE', 'BREAD'],
#  ['TEA',
#   'RICE',
#   'ORANGE',
#   'MAGGI',
#   'BUTTER',
#   'YOGURT',
#   'EGGS',
#   'SALT',
#   'BREAD',
#   'CORNFLAKES'],
#  ['BREAD', 'YOGURT', 'COFFEE', 'MILK', 'JAM', 'CORNFLAKES', 'COKE', 'SALT'],
#  ['CORNFLAKES', 'JAM', 'EGGS', 'PEPPER', 'BUTTER'],
#  ['PEPPER', 'COFFEE', 'COKE', 'JAM'],
#  ['MILK',
#   'BUTTER',
#   'CORNFLAKES',
#   'RICE',
#   'ORANGE',
#   'SUGAR',
#   'YOGURT',
#   'EGGS',
#   'SALT',
#   'BREAD'],
#  ['SUGAR', 'PEPPER', 'SALT'],
#  ['COKE', 'EGGS', 'COFFEE'],
#  ['TEA', 'MILK', 'MAGGI', 'SUGAR', 'JAM'],
#  ['CORNFLAKES', 'SUGAR', 'MILK', 'ORANGE', 'SALT'],
#  ['MILK', 'FLOUR', 'PEPPER'],
#  ['SUGAR', 'BUTTER', 'COKE'],
#  ['BREAD', 'RICE', 'JAM'],
#  ['MILK', 'COKE', 'ORANGE', 'FLOUR', 'MAGGI', 'JAM', 'YOGURT'],
#  ['SUGAR', 'PEPPER', 'BREAD', 'MAGGI'],
#  ['YOGURT',
#   'SUGAR',
#   'MAGGI',
#   'JAM',
#   'CORNFLAKES',
#   'BREAD',
#   'ORANGE',
#   'RICE',
#   'TEA',
#   'SALT'],
#  ['MAGGI',
#   'SALT',
#   'EGGS',
#   'JAM',
#   'ORANGE',
#   'SUGAR',
#   'TEA',
#   'MILK',
#   'YOGURT',
#   'RICE'],
#  ['EGGS',
#   'MILK',
#   'COFFEE',
#   'PEPPER',
#   'TEA',
#   'BREAD',
#   'SUGAR',
#   'MAGGI',
#   'YOGURT',
#   'FLOUR'],
#  ['CORNFLAKES', 'FLOUR', 'ORANGE', 'SALT', 'BUTTER', 'BREAD', 'MILK'],
#  ['ORANGE', 'BREAD', 'YOGURT', 'CORNFLAKES', 'RICE', 'PEPPER'],
#  ['MAGGI', 'MILK', 'FLOUR', 'COKE'],
#  ['YOGURT', 'BUTTER', 'SUGAR'],
#  ['TEA', 'SALT', 'CORNFLAKES', 'EGGS', 'JAM', 'COFFEE', 'ORANGE', 'PEPPER'],
#  ['BREAD',
#   'RICE',
#   'SALT',
#   'EGGS',
#   'MILK',
#   'YOGURT',
#   'PEPPER',
#   'MAGGI',
#   'COKE'],
#  ['COKE',
#   'SALT',
#   'RICE',
#   'FLOUR',
#   'CORNFLAKES',
#   'BREAD',
#   'ORANGE',
#   'BUTTER',
#   'JAM'],
#  ['EGGS', 'ORANGE', 'SALT'],
#  ['EGGS', 'JAM', 'SUGAR', 'COKE', 'ORANGE'],
#  ['BREAD',
#   'PEPPER',
#   'EGGS',
#   'BUTTER',
#   'MAGGI',
#   'COFFEE',
#   'SALT',
#   'COKE',
#   'ORANGE',
#   'RICE'],
#  ['CORNFLAKES', 'RICE', 'MAGGI', 'EGGS'],
#  ['PEPPER', 'BUTTER', 'BREAD', 'ORANGE', 'COFFEE', 'COKE', 'TEA', 'SALT'],
#  ['SUGAR', 'CORNFLAKES', 'YOGURT', 'BUTTER', 'FLOUR'],
#  ['COKE', 'BUTTER', 'FLOUR', 'SUGAR', 'TEA'],
#  ['SUGAR',
#   'CORNFLAKES',
#   'RICE',
#   'TEA',
#   'MILK',
#   'BUTTER',
#   'YOGURT',
#   'COFFEE',
#   'BREAD'],
#  ['BREAD',
#   'ORANGE',
#   'CORNFLAKES',
#   'SALT',
#   'YOGURT',
#   'TEA',
#   'BUTTER',
#   'PEPPER'],
#  ['BREAD', 'TEA', 'SUGAR', 'RICE', 'EGGS', 'CORNFLAKES'],
#  ['COFFEE', 'YOGURT', 'PEPPER', 'SUGAR', 'MILK'],
#  ['MILK', 'BUTTER', 'RICE', 'MAGGI', 'TEA', 'SALT', 'ORANGE', 'SUGAR'],
#  ['JAM',
#   'MILK',
#   'SALT',
#   'CORNFLAKES',
#   'ORANGE',
#   'BUTTER',
#   'COKE',
#   'BREAD',
#   'SUGAR'],
#  ['BUTTER', 'TEA', 'RICE', 'SALT'],
#  ['SALT', 'MILK', 'RICE', 'MAGGI', 'EGGS', 'SUGAR', 'BUTTER', 'CORNFLAKES'],
#  ['COFFEE', 'MILK', 'RICE', 'EGGS', 'JAM'],
#  ['FLOUR',
#   'CORNFLAKES',
#   'BREAD',
#   'COKE',
#   'SUGAR',
#   'MAGGI',
#   'COFFEE',
#   'EGGS',
#   'ORANGE',
#   'BUTTER'],
#  ['CORNFLAKES', 'SALT', 'MILK', 'COKE', 'EGGS', 'FLOUR', 'MAGGI'],
#  ['FLOUR',
#   'SUGAR',
#   'RICE',
#   'BREAD',
#   'JAM',
#   'ORANGE',
#   'MAGGI',
#   'EGGS',
#   'COFFEE',
#   'COKE'],
#  ['SUGAR', 'SALT', 'ORANGE', 'COKE', 'JAM', 'PEPPER', 'EGGS', 'BUTTER'],
#  ['COKE', 'MAGGI', 'MILK', 'COFFEE', 'EGGS', 'PEPPER', 'CORNFLAKES'],
#  ['MILK', 'PEPPER', 'COFFEE', 'BUTTER', 'COKE'],
#  ['MILK',
#   'ORANGE',
#   'BUTTER',
#   'YOGURT',
#   'EGGS',
#   'COFFEE',
#   'FLOUR',
#   'RICE',
#   'COKE'],
#  ['EGGS', 'SALT', 'SUGAR', 'BUTTER', 'CORNFLAKES', 'FLOUR', 'YOGURT', 'RICE'],
#  ['CORNFLAKES', 'SUGAR', 'EGGS', 'COKE'],
#  ['YOGURT', 'ORANGE', 'SALT', 'COFFEE', 'TEA', 'COKE'],
#  ['COFFEE', 'TEA', 'RICE', 'BUTTER', 'FLOUR', 'CORNFLAKES', 'ORANGE'],
#  ['TEA', 'COFFEE', 'FLOUR', 'EGGS', 'YOGURT', 'JAM'],
#  ['MAGGI', 'EGGS', 'COKE', 'BREAD', 'COFFEE', 'SALT', 'SUGAR', 'ORANGE'],
#  ['COFFEE', 'BREAD', 'MILK', 'YOGURT', 'FLOUR'],
#  ['CORNFLAKES',
#   'BREAD',
#   'COFFEE',
#   'YOGURT',
#   'ORANGE',
#   'SALT',
#   'BUTTER',
#   'TEA'],
#  ['FLOUR', 'SALT', 'SUGAR'],
#  ['PEPPER',
#   'YOGURT',
#   'TEA',
#   'SUGAR',
#   'ORANGE',
#   'COFFEE',
#   'MILK',
#   'CORNFLAKES',
#   'COKE',
#   'MAGGI'],
#  ['RICE', 'CORNFLAKES', 'TEA', 'YOGURT', 'JAM'],
#  ['EGGS', 'YOGURT', 'CORNFLAKES'],
#  ['PEPPER', 'COKE', 'SALT', 'COFFEE', 'BUTTER', 'RICE'],
#  ['ORANGE',
#   'YOGURT',
#   'CORNFLAKES',
#   'BREAD',
#   'JAM',
#   'MAGGI',
#   'COKE',
#   'FLOUR',
#   'COFFEE',
#   'SUGAR'],
#  ['PEPPER',
#   'BREAD',
#   'CORNFLAKES',
#   'FLOUR',
#   'SUGAR',
#   'ORANGE',
#   'COKE',
#   'JAM',
#   'MILK',
#   'TEA'],
#  ['EGGS', 'TEA', 'BUTTER', 'FLOUR'],
#  ['COKE', 'SUGAR', 'MILK', 'ORANGE', 'JAM', 'MAGGI', 'BREAD', 'COFFEE'],
#  ['FLOUR', 'COKE', 'YOGURT', 'BUTTER', 'SALT', 'TEA', 'MILK', 'CORNFLAKES'],
#  ['JAM', 'SALT', 'BREAD', 'RICE', 'CORNFLAKES', 'EGGS'],
#  ['RICE', 'COFFEE', 'TEA', 'SUGAR', 'MAGGI', 'BREAD', 'JAM'],
#  ['ORANGE', 'SALT', 'YOGURT'],
#  ['SUGAR',
#   'BREAD',
#   'RICE',
#   'CORNFLAKES',
#   'YOGURT',
#   'SALT',
#   'EGGS',
#   'COKE',
#   'ORANGE'],
#  ['PEPPER', 'ORANGE', 'YOGURT', 'JAM', 'FLOUR', 'BUTTER', 'MILK'],
#  ['COFFEE',
#   'SUGAR',
#   'PEPPER',
#   'BREAD',
#   'EGGS',
#   'SALT',
#   'BUTTER',
#   'ORANGE',
#   'CORNFLAKES',
#   'RICE'],
#  ['JAM', 'COKE', 'SUGAR'],
#  ['ORANGE', 'MAGGI', 'SALT', 'YOGURT'],
#  ['RICE', 'MILK', 'SALT'],
#  ['TEA',
#   'COFFEE',
#   'CORNFLAKES',
#   'SALT',
#   'RICE',
#   'PEPPER',
#   'COKE',
#   'FLOUR',
#   'BREAD'],
#  ['SUGAR',
#   'FLOUR',
#   'EGGS',
#   'MAGGI',
#   'PEPPER',
#   'CORNFLAKES',
#   'BREAD',
#   'YOGURT',
#   'COKE',
#   'JAM'],
#  ['CORNFLAKES',
#   'SUGAR',
#   'ORANGE',
#   'SALT',
#   'YOGURT',
#   'BUTTER',
#   'FLOUR',
#   'COKE'],
#  ['BREAD', 'MAGGI', 'FLOUR', 'ORANGE', 'TEA', 'BUTTER'],
#  ['BREAD',
#   'ORANGE',
#   'BUTTER',
#   'EGGS',
#   'SUGAR',
#   'PEPPER',
#   'YOGURT',
#   'MILK',
#   'RICE',
#   'FLOUR'],
#  ['FLOUR', 'TEA', 'COKE'],
#  ['ORANGE', 'TEA', 'COFFEE'],
#  ['BREAD', 'SUGAR', 'MILK', 'COKE', 'FLOUR'],
#  ['CORNFLAKES', 'JAM', 'COFFEE', 'RICE', 'COKE', 'ORANGE', 'BREAD', 'PEPPER'],
#  ['FLOUR',
#   'EGGS',
#   'BUTTER',
#   'MAGGI',
#   'RICE',
#   'MILK',
#   'PEPPER',
#   'SALT',
#   'COKE',
#   'BREAD'],
#  ['CORNFLAKES', 'COKE', 'TEA', 'SUGAR', 'BREAD', 'RICE', 'PEPPER', 'BUTTER'],
#  ['COFFEE', 'YOGURT', 'SALT', 'MILK', 'ORANGE', 'BUTTER'],
#  ['EGGS',
#   'TEA',
#   'MILK',
#   'FLOUR',
#   'ORANGE',
#   'SALT',
#   'BREAD',
#   'JAM',
#   'PEPPER',
#   'YOGURT'],
#  ['COFFEE', 'BUTTER', 'PEPPER'],
#  ['ORANGE', 'FLOUR', 'SALT', 'TEA', 'MILK'],
#  ['COKE', 'BUTTER', 'JAM'],
#  ['RICE', 'PEPPER', 'BREAD', 'MILK'],
#  ['COFFEE', 'COKE', 'JAM', 'BUTTER', 'YOGURT', 'MILK', 'MAGGI'],
#  ['ORANGE', 'JAM', 'RICE', 'SALT', 'MILK', 'FLOUR', 'CORNFLAKES', 'COFFEE'],
#  ['PEPPER',
#   'COFFEE',
#   'YOGURT',
#   'FLOUR',
#   'ORANGE',
#   'EGGS',
#   'JAM',
#   'SALT',
#   'MILK'],
#  ['BUTTER', 'SALT', 'SUGAR', 'BREAD', 'MILK', 'RICE', 'CORNFLAKES'],
#  ['SUGAR', 'CORNFLAKES', 'PEPPER', 'BREAD'],
#  ['PEPPER', 'EGGS', 'JAM', 'BUTTER', 'YOGURT', 'COKE', 'COFFEE', 'CORNFLAKES'],
#  ['TEA', 'MILK', 'PEPPER', 'SUGAR', 'COKE', 'EGGS', 'JAM'],
#  ['MILK', 'BUTTER', 'CORNFLAKES', 'JAM', 'COFFEE', 'FLOUR', 'COKE'],
#  ['CORNFLAKES', 'MILK', 'BREAD', 'COFFEE', 'TEA'],
#  ['MILK', 'SUGAR', 'MAGGI', 'COKE', 'JAM', 'BUTTER'],
#  ['EGGS', 'RICE', 'PEPPER'],
#  ['BUTTER', 'RICE', 'ORANGE'],
#  ['JAM', 'BREAD', 'EGGS', 'FLOUR', 'ORANGE', 'MAGGI'],
#  ['MAGGI', 'EGGS', 'CORNFLAKES', 'BUTTER', 'PEPPER'],
#  ['SALT', 'YOGURT', 'BUTTER'],
#  ['TEA', 'CORNFLAKES', 'ORANGE', 'SALT', 'BREAD', 'MILK', 'COFFEE', 'FLOUR'],
#  ['COKE', 'TEA', 'RICE', 'CORNFLAKES', 'SALT', 'FLOUR', 'MAGGI'],
#  ['FLOUR',
#   'MILK',
#   'ORANGE',
#   'CORNFLAKES',
#   'BUTTER',
#   'COKE',
#   'EGGS',
#   'COFFEE',
#   'BREAD',
#   'SALT'],
#  ['ORANGE',
#   'FLOUR',
#   'RICE',
#   'PEPPER',
#   'SALT',
#   'YOGURT',
#   'MAGGI',
#   'EGGS',
#   'TEA'],
#  ['ORANGE',
#   'JAM',
#   'SUGAR',
#   'EGGS',
#   'COFFEE',
#   'FLOUR',
#   'SALT',
#   'CORNFLAKES',
#   'BUTTER',
#   'MAGGI'],
#  ['RICE', 'YOGURT', 'BREAD'],
#  ['ORANGE', 'MAGGI', 'COKE', 'FLOUR', 'JAM', 'COFFEE', 'EGGS'],
#  ['JAM', 'RICE', 'COFFEE', 'MAGGI'],
#  ['MILK', 'BUTTER', 'ORANGE', 'FLOUR'],
#  ['EGGS', 'COFFEE', 'COKE', 'PEPPER', 'RICE', 'BUTTER', 'MILK'],
#  ['ORANGE', 'BUTTER', 'SUGAR', 'RICE', 'EGGS'],
#  ['SALT', 'TEA', 'ORANGE', 'FLOUR'],
#  ['SUGAR',
#   'SALT',
#   'BREAD',
#   'EGGS',
#   'RICE',
#   'MILK',
#   'YOGURT',
#   'ORANGE',
#   'CORNFLAKES',
#   'MAGGI'],
#  ['MAGGI',
#   'ORANGE',
#   'EGGS',
#   'SALT',
#   'TEA',
#   'BREAD',
#   'SUGAR',
#   'FLOUR',
#   'COKE',
#   'BUTTER'],
#  ['RICE',
#   'FLOUR',
#   'BUTTER',
#   'MILK',
#   'EGGS',
#   'CORNFLAKES',
#   'YOGURT',
#   'SUGAR',
#   'ORANGE'],
#  ['EGGS', 'FLOUR', 'TEA', 'COKE', 'MAGGI', 'CORNFLAKES', 'ORANGE', 'SALT'],
#  ['YOGURT', 'PEPPER', 'SALT', 'SUGAR', 'COKE', 'MAGGI', 'RICE', 'BREAD'],
#  ['JAM', 'MAGGI', 'COKE', 'EGGS', 'PEPPER', 'SALT', 'TEA', 'SUGAR'],
#  ['YOGURT', 'PEPPER', 'BUTTER', 'SUGAR', 'ORANGE', 'BREAD'],
#  ['BUTTER', 'BREAD', 'JAM', 'ORANGE'],
#  ['YOGURT', 'PEPPER', 'BREAD', 'COKE', 'BUTTER', 'FLOUR'],
#  ['SUGAR', 'COKE', 'JAM'],
#  ['EGGS',
#   'YOGURT',
#   'COKE',
#   'PEPPER',
#   'MAGGI',
#   'MILK',
#   'BUTTER',
#   'SUGAR',
#   'SALT',
#   'TEA'],
#  ['RICE', 'TEA', 'CORNFLAKES', 'JAM', 'MILK', 'ORANGE', 'BUTTER'],
#  ['BREAD', 'RICE', 'COFFEE', 'PEPPER', 'EGGS', 'SUGAR', 'YOGURT'],
#  ['SUGAR', 'MAGGI', 'RICE', 'PEPPER', 'SALT', 'BREAD', 'JAM'],
#  ['BUTTER', 'ORANGE', 'PEPPER'],
#  ['BUTTER',
#   'EGGS',
#   'MAGGI',
#   'SUGAR',
#   'ORANGE',
#   'CORNFLAKES',
#   'MILK',
#   'COFFEE',
#   'RICE',
#   'TEA'],
#  ['YOGURT', 'MILK', 'JAM', 'BREAD', 'SUGAR', 'SALT', 'COKE'],
#  ['PEPPER', 'MILK', 'JAM', 'RICE'],
#  ['SALT', 'SUGAR', 'COKE', 'CORNFLAKES', 'ORANGE', 'PEPPER', 'MAGGI', 'EGGS'],
#  ['SALT', 'YOGURT', 'COKE'],
#  ['YOGURT',
#   'MAGGI',
#   'EGGS',
#   'SALT',
#   'COKE',
#   'ORANGE',
#   'MILK',
#   'RICE',
#   'BUTTER',
#   'FLOUR'],
#  ['BUTTER', 'MAGGI', 'JAM', 'RICE', 'CORNFLAKES'],
#  ['CORNFLAKES', 'EGGS', 'RICE', 'PEPPER', 'COFFEE'],
#  ['SUGAR', 'BUTTER', 'CORNFLAKES'],
#  ['PEPPER',
#   'EGGS',
#   'MILK',
#   'BUTTER',
#   'JAM',
#   'COFFEE',
#   'SUGAR',
#   'TEA',
#   'RICE',
#   'BREAD'],
#  ['COKE', 'RICE', 'CORNFLAKES', 'COFFEE', 'BREAD', 'SUGAR', 'PEPPER', 'MAGGI'],
#  ['YOGURT', 'SUGAR', 'EGGS', 'BUTTER', 'CORNFLAKES', 'ORANGE'],
#  ['COKE',
#   'MAGGI',
#   'JAM',
#   'COFFEE',
#   'ORANGE',
#   'RICE',
#   'TEA',
#   'YOGURT',
#   'FLOUR'],
#  ['JAM', 'MAGGI', 'BUTTER', 'COFFEE'],
#  ['BREAD', 'EGGS', 'YOGURT', 'ORANGE', 'PEPPER'],
#  ['CORNFLAKES', 'EGGS', 'SALT', 'COKE', 'COFFEE'],
#  ['COFFEE',
#   'BUTTER',
#   'EGGS',
#   'BREAD',
#   'JAM',
#   'FLOUR',
#   'MILK',
#   'PEPPER',
#   'ORANGE'],
#  ['ORANGE', 'RICE', 'MILK', 'FLOUR', 'CORNFLAKES', 'BREAD'],
#  ['JAM', 'RICE', 'MILK', 'BUTTER', 'EGGS', 'BREAD'],
#  ['CORNFLAKES',
#   'SUGAR',
#   'FLOUR',
#   'PEPPER',
#   'MAGGI',
#   'SALT',
#   'BREAD',
#   'BUTTER',
#   'MILK',
#   'JAM'],
#  ['MAGGI', 'CORNFLAKES', 'RICE', 'SALT'],
#  ['SALT', 'COKE', 'FLOUR', 'BREAD', 'COFFEE', 'RICE', 'CORNFLAKES', 'BUTTER'],
#  ['FLOUR', 'PEPPER', 'SUGAR', 'MAGGI', 'EGGS', 'ORANGE', 'CORNFLAKES'],
#  ['COFFEE',
#   'BREAD',
#   'TEA',
#   'ORANGE',
#   'JAM',
#   'COKE',
#   'YOGURT',
#   'MILK',
#   'CORNFLAKES'],
#  ['FLOUR',
#   'BUTTER',
#   'YOGURT',
#   'COKE',
#   'COFFEE',
#   'EGGS',
#   'RICE',
#   'PEPPER',
#   'CORNFLAKES',
#   'JAM'],
#  ['COKE', 'RICE', 'SUGAR', 'MILK', 'FLOUR'],
#  ['COKE', 'SALT', 'PEPPER', 'FLOUR', 'MILK', 'TEA', 'SUGAR'],
#  ['SALT',
#   'BREAD',
#   'CORNFLAKES',
#   'JAM',
#   'MAGGI',
#   'YOGURT',
#   'ORANGE',
#   'BUTTER',
#   'FLOUR'],
#  ['COKE', 'EGGS', 'MAGGI', 'FLOUR', 'COFFEE', 'TEA', 'ORANGE'],
#  ['COKE', 'JAM', 'ORANGE', 'COFFEE', 'SUGAR'],
#  ['SUGAR', 'EGGS', 'ORANGE', 'FLOUR', 'BREAD', 'PEPPER', 'COFFEE'],
#  ['MAGGI', 'SALT', 'YOGURT', 'RICE', 'PEPPER'],
#  ['SALT', 'MILK', 'TEA'],
#  ['SALT', 'PEPPER', 'ORANGE', 'BUTTER'],
#  ['MILK', 'TEA', 'COKE', 'SALT', 'BUTTER', 'PEPPER', 'RICE'],
#  ['BUTTER', 'PEPPER', 'SUGAR', 'JAM', 'ORANGE', 'CORNFLAKES'],
#  ['RICE', 'MAGGI', 'YOGURT', 'EGGS'],
#  ['ORANGE', 'CORNFLAKES', 'SALT', 'PEPPER', 'MILK'],
#  ['MAGGI', 'SALT', 'PEPPER', 'BREAD', 'TEA', 'SUGAR', 'ORANGE'],
#  ['FLOUR', 'SALT', 'BUTTER', 'COFFEE'],
#  ['BUTTER',
#   'SALT',
#   'PEPPER',
#   'MAGGI',
#   'EGGS',
#   'TEA',
#   'YOGURT',
#   'COFFEE',
#   'BREAD',
#   'SUGAR'],
#  ['RICE', 'COKE', 'FLOUR', 'BUTTER', 'JAM', 'MAGGI', 'PEPPER', 'YOGURT'],
#  ['COFFEE', 'EGGS', 'SALT'],
#  ['COKE',
#   'FLOUR',
#   'RICE',
#   'CORNFLAKES',
#   'MAGGI',
#   'COFFEE',
#   'JAM',
#   'YOGURT',
#   'MILK'],
# ...
#  ['BUTTER',
#   'EGGS',
#   'RICE',
#   'PEPPER',
#   'JAM',
#   'MAGGI',
#   'YOGURT',
#   'COFFEE',
#   'SUGAR'],
#  ['COKE', 'RICE', 'FLOUR', 'YOGURT', 'ORANGE', 'SALT', 'MILK', 'EGGS', 'TEA'],
#  ['YOGURT', 'TEA', 'COFFEE', 'ORANGE', 'PEPPER', 'MAGGI'],
#  ['FLOUR',
#   'MILK',
#   'MAGGI',
#   'CORNFLAKES',
#   'SALT',
#   'BUTTER',
#   'ORANGE',
#   'RICE',
#   'EGGS'],
#  ['MAGGI', 'COFFEE', 'JAM', 'FLOUR', 'SALT', 'ORANGE'],
#  ['COKE',
#   'MILK',
#   'RICE',
#   'CORNFLAKES',
#   'BUTTER',
#   'FLOUR',
#   'ORANGE',
#   'JAM',
#   'SUGAR',
#   'COFFEE'],
#  ['YOGURT', 'PEPPER', 'JAM', 'RICE', 'COFFEE', 'BREAD', 'ORANGE', 'TEA'],
#  ['COKE', 'PEPPER', 'TEA', 'MILK', 'JAM', 'RICE'],
#  ['BUTTER', 'COKE', 'BREAD', 'JAM', 'YOGURT', 'CORNFLAKES'],
#  ['BREAD', 'JAM', 'MAGGI', 'SUGAR', 'COFFEE'],
#  ['ORANGE', 'JAM', 'COKE', 'TEA', 'MAGGI', 'YOGURT', 'EGGS'],
#  ['MAGGI', 'MILK', 'ORANGE', 'PEPPER', 'FLOUR', 'YOGURT', 'EGGS'],
#  ['COFFEE', 'BREAD', 'JAM', 'ORANGE', 'YOGURT'],
#  ['SALT',
#   'COFFEE',
#   'EGGS',
#   'CORNFLAKES',
#   'TEA',
#   'BUTTER',
#   'ORANGE',
#   'PEPPER',
#   'BREAD'],
#  ['JAM', 'TEA', 'EGGS', 'ORANGE', 'BUTTER', 'COKE'],
#  ['SUGAR', 'TEA', 'SALT', 'BUTTER', 'EGGS', 'JAM'],
#  ['EGGS',
#   'ORANGE',
#   'RICE',
#   'MAGGI',
#   'SUGAR',
#   'TEA',
#   'PEPPER',
#   'BREAD',
#   'SALT'],
#  ['TEA', 'COKE', 'MAGGI', 'SUGAR', 'YOGURT', 'SALT'],
#  ['COFFEE', 'MILK', 'BUTTER'],
#  ['SALT', 'TEA', 'FLOUR', 'EGGS'],
#  ['ORANGE', 'SUGAR', 'EGGS', 'FLOUR'],
#  ['ORANGE', 'COKE', 'YOGURT', 'BREAD', 'FLOUR', 'CORNFLAKES', 'COFFEE', 'TEA'],
#  ['COKE', 'RICE', 'SALT'],
#  ['JAM', 'COFFEE', 'BUTTER', 'PEPPER', 'BREAD'],
#  ['COFFEE', 'COKE', 'TEA', 'EGGS'],
#  ['ORANGE', 'PEPPER', 'CORNFLAKES', 'EGGS'],
#  ['COKE', 'CORNFLAKES', 'SUGAR', 'SALT', 'TEA', 'BREAD'],
#  ['JAM', 'COFFEE', 'COKE', 'YOGURT', 'RICE', 'BUTTER', 'TEA', 'MILK', 'MAGGI'],
#  ['RICE', 'TEA', 'ORANGE', 'COFFEE', 'YOGURT', 'BUTTER'],
#  ['RICE', 'MILK', 'EGGS', 'COKE', 'SALT', 'YOGURT', 'CORNFLAKES', 'MAGGI'],
#  ['BUTTER', 'SUGAR', 'EGGS', 'YOGURT'],
#  ['TEA', 'BREAD', 'MILK', 'YOGURT', 'COFFEE', 'RICE'],
#  ['FLOUR', 'YOGURT', 'SALT', 'SUGAR', 'MAGGI', 'COKE'],
#  ['SALT',
#   'MAGGI',
#   'YOGURT',
#   'RICE',
#   'MILK',
#   'ORANGE',
#   'BUTTER',
#   'BREAD',
#   'EGGS'],
#  ['SUGAR', 'JAM', 'PEPPER', 'EGGS', 'BREAD', 'ORANGE', 'YOGURT'],
#  ['JAM',
#   'BREAD',
#   'EGGS',
#   'RICE',
#   'ORANGE',
#   'SALT',
#   'SUGAR',
#   'COFFEE',
#   'BUTTER',
#   'MAGGI'],
#  ['MILK',
#   'ORANGE',
#   'SUGAR',
#   'FLOUR',
#   'TEA',
#   'SALT',
#   'YOGURT',
#   'COKE',
#   'COFFEE'],
#  ['COFFEE', 'BREAD', 'SUGAR', 'MAGGI', 'CORNFLAKES'],
#  ['TEA', 'BREAD', 'MAGGI', 'YOGURT', 'EGGS', 'FLOUR', 'SUGAR'],
#  ['JAM', 'CORNFLAKES', 'MILK', 'RICE'],
#  ['BREAD', 'PEPPER', 'MAGGI', 'TEA', 'RICE'],
#  ['YOGURT',
#   'CORNFLAKES',
#   'BREAD',
#   'COKE',
#   'SUGAR',
#   'BUTTER',
#   'TEA',
#   'FLOUR',
#   'MAGGI',
#   'RICE'],
#  ['MAGGI', 'JAM', 'BUTTER', 'RICE', 'YOGURT', 'SALT', 'CORNFLAKES', 'SUGAR'],
#  ['BREAD', 'SALT', 'JAM', 'EGGS', 'MILK', 'CORNFLAKES'],
#  ['JAM', 'CORNFLAKES', 'PEPPER', 'RICE', 'COFFEE'],
#  ['RICE', 'YOGURT', 'MILK', 'CORNFLAKES', 'SALT', 'BUTTER', 'COFFEE', 'EGGS'],
#  ['PEPPER', 'YOGURT', 'COFFEE'],
#  ['BREAD',
#   'SALT',
#   'TEA',
#   'FLOUR',
#   'YOGURT',
#   'ORANGE',
#   'MILK',
#   'PEPPER',
#   'CORNFLAKES'],
#  ['SALT', 'RICE', 'COKE', 'CORNFLAKES'],
#  ['TEA', 'MAGGI', 'MILK', 'JAM', 'RICE', 'BREAD', 'SUGAR'],
#  ['SUGAR', 'COFFEE', 'CORNFLAKES', 'SALT', 'BUTTER', 'COKE', 'MILK'],
#  ['SUGAR', 'MILK', 'JAM', 'MAGGI', 'YOGURT'],
#  ['COFFEE', 'JAM', 'FLOUR', 'MILK', 'PEPPER'],
#  ['RICE', 'BUTTER', 'MAGGI', 'PEPPER', 'COFFEE', 'BREAD', 'ORANGE', 'COKE'],
#  ['FLOUR', 'BUTTER', 'BREAD', 'JAM', 'SALT'],
#  ['FLOUR', 'MILK', 'BUTTER', 'JAM', 'TEA', 'EGGS', 'RICE'],
#  ['BREAD', 'MAGGI', 'COFFEE', 'ORANGE', 'PEPPER', 'COKE', 'BUTTER'],
#  ['MAGGI', 'YOGURT', 'BREAD', 'EGGS', 'TEA'],
#  ['MILK', 'SALT', 'ORANGE', 'COFFEE', 'JAM', 'CORNFLAKES'],
#  ['JAM', 'CORNFLAKES', 'COFFEE', 'COKE', 'SUGAR', 'BREAD'],
#  ['PEPPER', 'JAM', 'RICE'],
#  ['ORANGE', 'FLOUR', 'COFFEE', 'JAM', 'CORNFLAKES', 'BUTTER'],
#  ['RICE', 'PEPPER', 'TEA', 'ORANGE', 'COKE'],
#  ['COFFEE', 'BREAD', 'FLOUR', 'CORNFLAKES', 'YOGURT', 'SALT', 'COKE', 'JAM'],
#  ['COKE', 'SALT', 'RICE', 'BUTTER', 'CORNFLAKES', 'EGGS'],
#  ['COFFEE',
#   'CORNFLAKES',
#   'EGGS',
#   'BREAD',
#   'SALT',
#   'FLOUR',
#   'TEA',
#   'YOGURT',
#   'MAGGI',
#   'MILK'],
#  ['PEPPER',
#   'YOGURT',
#   'FLOUR',
#   'ORANGE',
#   'MILK',
#   'BREAD',
#   'SALT',
#   'COKE',
#   'CORNFLAKES',
#   'EGGS'],
#  ['RICE', 'EGGS', 'SUGAR', 'BREAD'],
#  ['CORNFLAKES', 'COKE', 'RICE', 'TEA', 'ORANGE'],
#  ['PEPPER',
#   'ORANGE',
#   'MILK',
#   'JAM',
#   'COKE',
#   'SALT',
#   'YOGURT',
#   'CORNFLAKES',
#   'TEA',
#   'BUTTER'],
#  ['PEPPER', 'CORNFLAKES', 'BUTTER', 'EGGS', 'TEA', 'SALT', 'MAGGI', 'COKE'],
#  ['BUTTER', 'RICE', 'SALT', 'JAM', 'COFFEE', 'SUGAR'],
#  ['SUGAR', 'PEPPER', 'MILK', 'COFFEE', 'RICE'],
#  ['EGGS', 'SUGAR', 'TEA', 'CORNFLAKES', 'RICE'],
#  ['RICE', 'ORANGE', 'BUTTER', 'SUGAR'],
#  ['FLOUR',
#   'MILK',
#   'YOGURT',
#   'ORANGE',
#   'PEPPER',
#   'MAGGI',
#   'COKE',
#   'SALT',
#   'CORNFLAKES'],
#  ['FLOUR', 'CORNFLAKES', 'SALT', 'JAM', 'EGGS', 'MILK', 'RICE', 'ORANGE'],
#  ['YOGURT',
#   'COFFEE',
#   'EGGS',
#   'ORANGE',
#   'COKE',
#   'SALT',
#   'MAGGI',
#   'BUTTER',
#   'RICE',
#   'MILK'],
#  ['PEPPER', 'MAGGI', 'COFFEE'],
#  ['PEPPER', 'MAGGI', 'SALT'],
#  ['RICE', 'BREAD', 'COFFEE', 'CORNFLAKES', 'BUTTER', 'JAM'],
#  ['COFFEE', 'PEPPER', 'EGGS', 'SALT'],
#  ['COFFEE', 'EGGS', 'CORNFLAKES', 'SUGAR', 'FLOUR', 'SALT'],
#  ['MAGGI',
#   'FLOUR',
#   'TEA',
#   'PEPPER',
#   'SUGAR',
#   'YOGURT',
#   'RICE',
#   'BREAD',
#   'CORNFLAKES',
#   'COFFEE'],
#  ['COFFEE', 'BUTTER', 'SUGAR', 'RICE'],
#  ['SUGAR', 'RICE', 'TEA'],
#  ['PEPPER', 'CORNFLAKES', 'RICE', 'COKE', 'SALT', 'SUGAR'],
#  ['TEA', 'COFFEE', 'SUGAR'],
#  ['ORANGE', 'PEPPER', 'EGGS', 'CORNFLAKES', 'RICE', 'COFFEE'],
#  ['COKE',
#   'ORANGE',
#   'EGGS',
#   'BREAD',
#   'MILK',
#   'RICE',
#   'FLOUR',
#   'MAGGI',
#   'COFFEE',
#   'BUTTER'],
#  ['TEA', 'JAM', 'PEPPER', 'EGGS', 'COKE', 'MAGGI', 'COFFEE'],
#  ['BREAD', 'COKE', 'TEA'],
#  ['TEA', 'ORANGE', 'SUGAR'],
#  ['COFFEE', 'TEA', 'MAGGI'],
#  ['ORANGE', 'RICE', 'JAM', 'SUGAR'],
#  ['EGGS', 'COFFEE', 'CORNFLAKES', 'MILK', 'PEPPER', 'SUGAR'],
#  ['YOGURT',
#   'RICE',
#   'ORANGE',
#   'MAGGI',
#   'CORNFLAKES',
#   'TEA',
#   'SALT',
#   'EGGS',
#   'SUGAR'],
#  ['SALT', 'ORANGE', 'CORNFLAKES', 'FLOUR'],
#  ['PEPPER',
#   'YOGURT',
#   'TEA',
#   'BUTTER',
#   'COFFEE',
#   'SALT',
#   'CORNFLAKES',
#   'ORANGE',
#   'RICE'],
#  ['MILK', 'PEPPER', 'TEA', 'CORNFLAKES', 'BREAD', 'FLOUR'],
#  ['SUGAR', 'FLOUR', 'RICE', 'YOGURT', 'TEA', 'COFFEE'],
#  ['FLOUR', 'CORNFLAKES', 'JAM', 'COFFEE', 'RICE', 'PEPPER'],
#  ['JAM', 'BUTTER', 'EGGS', 'SALT', 'FLOUR'],
#  ['SUGAR',
#   'PEPPER',
#   'ORANGE',
#   'YOGURT',
#   'CORNFLAKES',
#   'COFFEE',
#   'JAM',
#   'BREAD'],
#  ['MILK',
#   'EGGS',
#   'SALT',
#   'ORANGE',
#   'PEPPER',
#   'COFFEE',
#   'SUGAR',
#   'JAM',
#   'MAGGI',
#   'YOGURT'],
#  ['YOGURT', 'FLOUR', 'MAGGI', 'ORANGE', 'TEA'],
#  ['MAGGI',
#   'BREAD',
#   'RICE',
#   'CORNFLAKES',
#   'SALT',
#   'JAM',
#   'SUGAR',
#   'COKE',
#   'PEPPER',
#   'BUTTER'],
#  ['RICE', 'MAGGI', 'FLOUR', 'BUTTER', 'CORNFLAKES'],
#  ['BREAD', 'BUTTER', 'EGGS'],
#  ['MAGGI', 'ORANGE', 'YOGURT', 'RICE', 'BUTTER', 'CORNFLAKES', 'JAM'],
#  ['JAM', 'EGGS', 'TEA', 'ORANGE', 'MILK', 'FLOUR', 'COFFEE', 'PEPPER', 'SALT'],
#  ['YOGURT',
#   'CORNFLAKES',
#   'JAM',
#   'MAGGI',
#   'SALT',
#   'PEPPER',
#   'BREAD',
#   'RICE',
#   'MILK'],
#  ['ORANGE', 'BUTTER', 'COFFEE', 'JAM', 'FLOUR', 'COKE', 'SALT', 'TEA'],
#  ['BUTTER', 'BREAD', 'MILK'],
#  ['RICE', 'EGGS', 'SALT', 'YOGURT'],
#  ['TEA', 'COKE', 'ORANGE', 'FLOUR'],
#  ['FLOUR',
#   'ORANGE',
#   'RICE',
#   'MAGGI',
#   'CORNFLAKES',
#   'MILK',
#   'COFFEE',
#   'SALT',
#   'SUGAR'],
#  ['FLOUR', 'EGGS', 'BUTTER', 'TEA', 'COFFEE', 'COKE'],
#  ['SALT', 'CORNFLAKES', 'BUTTER', 'FLOUR', 'SUGAR', 'ORANGE', 'RICE'],
#  ['EGGS', 'MAGGI', 'PEPPER', 'RICE'],
#  ['SALT', 'RICE', 'MAGGI', 'PEPPER', 'COFFEE', 'COKE', 'CORNFLAKES'],
#  ['SALT', 'TEA', 'EGGS'],
#  ['BREAD', 'RICE', 'MAGGI', 'JAM'],
#  ['ORANGE', 'CORNFLAKES', 'MILK'],
#  ['BREAD', 'COKE', 'BUTTER', 'YOGURT', 'PEPPER', 'FLOUR'],
#  ['BREAD', 'COFFEE', 'PEPPER', 'BUTTER'],
#  ['COKE', 'RICE', 'SUGAR', 'COFFEE', 'SALT', 'YOGURT', 'PEPPER'],
#  ['BUTTER', 'PEPPER', 'ORANGE', 'TEA', 'JAM', 'YOGURT'],
#  ['MAGGI', 'PEPPER', 'SUGAR', 'TEA', 'MILK'],
#  ['CORNFLAKES', 'COKE', 'PEPPER', 'BUTTER', 'TEA', 'BREAD', 'MILK', 'SUGAR'],
#  ['ORANGE',
#   'BUTTER',
#   'COFFEE',
#   'SUGAR',
#   'MAGGI',
#   'COKE',
#   'TEA',
#   'PEPPER',
#   'RICE',
#   'SALT'],
#  ['FLOUR',
#   'BREAD',
#   'SALT',
#   'YOGURT',
#   'TEA',
#   'ORANGE',
#   'CORNFLAKES',
#   'PEPPER',
#   'RICE'],
#  ['YOGURT', 'ORANGE', 'EGGS', 'JAM', 'BUTTER'],
#  ['MILK',
#   'BUTTER',
#   'EGGS',
#   'ORANGE',
#   'COKE',
#   'COFFEE',
#   'SALT',
#   'RICE',
#   'PEPPER'],
#  ['SALT',
#   'COKE',
#   'ORANGE',
#   'PEPPER',
#   'MILK',
#   'EGGS',
#   'FLOUR',
#   'SUGAR',
#   'COFFEE',
#   'BREAD'],
#  ['MAGGI', 'RICE', 'MILK', 'COFFEE'],
#  ['COFFEE',
#   'BREAD',
#   'SUGAR',
#   'PEPPER',
#   'JAM',
#   'BUTTER',
#   'MILK',
#   'FLOUR',
#   'EGGS'],
#  ['JAM',
#   'SALT',
#   'MILK',
#   'CORNFLAKES',
#   'SUGAR',
#   'COFFEE',
#   'YOGURT',
#   'FLOUR',
#   'TEA',
#   'COKE'],
#  ['COKE',
#   'JAM',
#   'PEPPER',
#   'MAGGI',
#   'SUGAR',
#   'ORANGE',
#   'BREAD',
#   'RICE',
#   'MILK',
#   'COFFEE'],
#  ['YOGURT', 'BUTTER', 'SUGAR', 'PEPPER', 'CORNFLAKES'],
#  ['ORANGE', 'BREAD', 'TEA', 'BUTTER', 'FLOUR'],
#  ['EGGS', 'SUGAR', 'COKE'],
#  ['MILK', 'CORNFLAKES', 'PEPPER', 'JAM', 'ORANGE'],
#  ['TEA', 'BREAD', 'SALT', 'CORNFLAKES', 'RICE'],
#  ['MAGGI',
#   'SUGAR',
#   'FLOUR',
#   'SALT',
#   'COFFEE',
#   'CORNFLAKES',
#   'MILK',
#   'JAM',
#   'BUTTER'],
#  ['COFFEE', 'SALT', 'RICE', 'YOGURT', 'MILK', 'ORANGE', 'BUTTER'],
#  ['COFFEE', 'SUGAR', 'MILK', 'JAM', 'MAGGI', 'BUTTER', 'TEA', 'SALT'],
#  ['FLOUR',
#   'ORANGE',
#   'RICE',
#   'YOGURT',
#   'MAGGI',
#   'SUGAR',
#   'JAM',
#   'SALT',
#   'PEPPER'],
#  ['EGGS',
#   'ORANGE',
#   'YOGURT',
#   'BUTTER',
#   'MAGGI',
#   'SUGAR',
#   'MILK',
#   'JAM',
#   'COKE'],
#  ['BREAD',
#   'COFFEE',
#   'JAM',
#   'COKE',
#   'SALT',
#   'RICE',
#   'ORANGE',
#   'EGGS',
#   'SUGAR',
#   'BUTTER'],
#  ['TEA', 'FLOUR', 'BREAD', 'SALT', 'EGGS', 'MAGGI', 'MILK', 'BUTTER'],
#  ['SALT', 'BUTTER', 'COKE', 'FLOUR', 'BREAD', 'YOGURT', 'CORNFLAKES'],
#  ['BUTTER', 'YOGURT', 'JAM'],
#  ['BREAD', 'CORNFLAKES', 'SUGAR', 'YOGURT', 'TEA', 'ORANGE', 'COKE', 'MILK'],
#  ['COFFEE', 'RICE', 'BREAD'],
#  ['CORNFLAKES', 'COKE', 'EGGS', 'YOGURT', 'COFFEE', 'MAGGI', 'RICE', 'JAM'],
#  ['MAGGI', 'CORNFLAKES', 'RICE', 'MILK'],
#  ['SUGAR',
#   'MAGGI',
#   'YOGURT',
#   'ORANGE',
#   'RICE',
#   'PEPPER',
#   'COKE',
#   'MILK',
#   'TEA',
#   'BREAD'],
#  ['FLOUR', 'COFFEE', 'MILK', 'TEA', 'MAGGI', 'RICE', 'ORANGE', 'BREAD'],
#  ['EGGS', 'COFFEE', 'MILK', 'PEPPER'],
#  ['MAGGI',
#   'EGGS',
#   'COKE',
#   'SUGAR',
#   'TEA',
#   'ORANGE',
#   'CORNFLAKES',
#   'JAM',
#   'COFFEE'],
#  ['FLOUR',
#   'PEPPER',
#   'YOGURT',
#   'BUTTER',
#   'SALT',
#   'EGGS',
#   'COKE',
#   'ORANGE',
#   'MAGGI',
#   'TEA'],
#  ['YOGURT', 'BUTTER', 'ORANGE', 'COKE'],
#  ['COKE', 'PEPPER', 'JAM', 'BREAD', 'SALT', 'BUTTER'],
#  ['COFFEE', 'RICE', 'BREAD'],
#  ['PEPPER', 'BUTTER', 'JAM', 'RICE', 'SALT'],
#  ['COFFEE', 'FLOUR', 'PEPPER'],
#  ['CORNFLAKES', 'SALT', 'MAGGI', 'MILK', 'BREAD', 'RICE', 'COKE', 'SUGAR'],
#  ['FLOUR',
#   'YOGURT',
#   'CORNFLAKES',
#   'ORANGE',
#   'BUTTER',
#   'COKE',
#   'COFFEE',
#   'RICE',
#   'TEA',
#   'SUGAR'],
#  ['ORANGE', 'COKE', 'SUGAR', 'PEPPER', 'FLOUR', 'JAM', 'RICE'],
#  ['MILK', 'EGGS', 'CORNFLAKES'],
#  ['JAM', 'BUTTER', 'COFFEE', 'COKE', 'ORANGE'],
#  ['PEPPER', 'MAGGI', 'RICE', 'COFFEE'],
#  ['MILK', 'JAM', 'COFFEE', 'SUGAR', 'EGGS'],
#  ['BUTTER', 'PEPPER', 'SALT', 'CORNFLAKES', 'TEA', 'BREAD'],
#  ['COFFEE',
#   'FLOUR',
#   'PEPPER',
#   'YOGURT',
#   'EGGS',
#   'BUTTER',
#   'TEA',
#   'MILK',
#   'JAM',
#   'BREAD'],
#  ['SALT', 'CORNFLAKES', 'SUGAR', 'EGGS', 'BUTTER'],
#  ['MILK', 'RICE', 'SUGAR'],
#  ['SUGAR', 'BREAD', 'COFFEE'],
#  ['MAGGI', 'CORNFLAKES', 'SALT', 'ORANGE'],
#  ['MILK',
#   'COKE',
#   'BREAD',
#   'PEPPER',
#   'SALT',
#   'YOGURT',
#   'TEA',
#   'JAM',
#   'COFFEE',
#   'MAGGI'],
#  ['BREAD', 'JAM', 'EGGS', 'SUGAR', 'RICE'],
#  ['SALT', 'JAM', 'FLOUR', 'YOGURT'],
#  ['EGGS', 'CORNFLAKES', 'FLOUR', 'ORANGE'],
#  ['EGGS',
#   'MILK',
#   'BREAD',
#   'BUTTER',
#   'PEPPER',
#   'YOGURT',
#   'COKE',
#   'TEA',
#   'MAGGI'],
#  ['JAM',
#   'PEPPER',
#   'YOGURT',
#   'MAGGI',
#   'SUGAR',
#   'MILK',
#   'BREAD',
#   'SALT',
#   'FLOUR',
#   'TEA'],
#  ['JAM', 'COKE', 'COFFEE', 'MAGGI'],
#  ['MAGGI',
#   'SALT',
#   'MILK',
#   'BUTTER',
#   'ORANGE',
#   'TEA',
#   'COFFEE',
#   'COKE',
#   'CORNFLAKES',
#   'EGGS'],
#  ['MAGGI',
#   'PEPPER',
#   'JAM',
#   'COFFEE',
#   'MILK',
#   'ORANGE',
#   'TEA',
#   'COKE',
#   'FLOUR'],
#  ['ORANGE',
#   'BUTTER',
#   'TEA',
#   'JAM',
#   'SUGAR',
#   'SALT',
#   'CORNFLAKES',
#   'MAGGI',
#   'BREAD',
#   'COKE'],
#  ['COFFEE', 'SALT', 'BUTTER', 'ORANGE', 'COKE', 'CORNFLAKES', 'PEPPER'],
#  ['COKE', 'BUTTER', 'ORANGE', 'SALT'],
#  ['YOGURT', 'CORNFLAKES', 'TEA', 'COFFEE', 'ORANGE', 'SUGAR', 'SALT'],
#  ['RICE',
#   'SALT',
#   'SUGAR',
#   'COFFEE',
#   'ORANGE',
#   'PEPPER',
#   'BUTTER',
#   'CORNFLAKES',
#   'BREAD'],
#  ['CORNFLAKES', 'EGGS', 'RICE', 'COFFEE', 'BUTTER', 'JAM', 'ORANGE'],
#  ['JAM', 'MILK', 'CORNFLAKES', 'BREAD', 'ORANGE'],
#  ['TEA', 'SALT', 'FLOUR', 'RICE', 'COKE', 'COFFEE', 'YOGURT'],
#  ['EGGS', 'JAM', 'SUGAR', 'YOGURT', 'BREAD', 'TEA', 'BUTTER'],
#  ['EGGS', 'RICE', 'YOGURT'],
#  ['BUTTER', 'TEA', 'MILK', 'COKE', 'PEPPER', 'EGGS', 'CORNFLAKES'],
#  ['FLOUR',
#   'JAM',
#   'SUGAR',
#   'COFFEE',
#   'BUTTER',
#   'RICE',
#   'TEA',
#   'BREAD',
#   'ORANGE'],
#  ['PEPPER', 'ORANGE', 'YOGURT', 'TEA'],
#  ['PEPPER', 'JAM', 'ORANGE', 'COFFEE', 'MAGGI'],
#  ['YOGURT', 'TEA', 'ORANGE', 'SUGAR', 'COKE', 'FLOUR'],
#  ['EGGS', 'FLOUR', 'JAM', 'SALT', 'RICE', 'YOGURT', 'COKE', 'TEA', 'ORANGE'],
#  ['YOGURT',
#   'RICE',
#   'MAGGI',
#   'COFFEE',
#   'BREAD',
#   'SALT',
#   'BUTTER',
#   'PEPPER',
#   'FLOUR',
#   'JAM'],
#  ['YOGURT', 'RICE', 'SUGAR', 'JAM', 'MILK', 'FLOUR', 'ORANGE', 'PEPPER'],
#  ['EGGS', 'SUGAR', 'FLOUR', 'JAM', 'COFFEE'],
#  ['SUGAR',
#   'COKE',
#   'PEPPER',
#   'COFFEE',
#   'FLOUR',
#   'SALT',
#   'EGGS',
#   'MILK',
#   'YOGURT',
#   'TEA'],
#  ['MILK', 'ORANGE', 'EGGS', 'SALT'],
#  ['FLOUR', 'SUGAR', 'TEA', 'PEPPER', 'JAM', 'YOGURT', 'EGGS'],
#  ['CORNFLAKES', 'BREAD', 'BUTTER'],
#  ['PEPPER', 'COFFEE', 'MILK'],
#  ['JAM', 'BUTTER', 'CORNFLAKES', 'RICE', 'SALT'],
#  ['ORANGE', 'YOGURT', 'COFFEE', 'CORNFLAKES'],
#  ['EGGS', 'CORNFLAKES', 'FLOUR', 'MAGGI'],
#  ['MILK', 'SUGAR', 'TEA', 'FLOUR', 'COFFEE'],
#  ['CORNFLAKES', 'PEPPER', 'MILK', 'MAGGI', 'BREAD'],
#  ['COFFEE', 'SUGAR', 'COKE', 'RICE', 'PEPPER'],
#  ['BUTTER', 'PEPPER', 'MILK', 'FLOUR', 'TEA', 'SALT', 'RICE'],
#  ['COFFEE', 'JAM', 'MAGGI'],
#  ['ORANGE', 'BUTTER', 'BREAD', 'MILK'],
#  ['YOGURT', 'MILK', 'ORANGE'],
#  ['SALT', 'RICE', 'COFFEE', 'MAGGI', 'COKE', 'FLOUR', 'BUTTER', 'EGGS'],
#  ['SALT',
#   'PEPPER',
#   'COFFEE',
#   'RICE',
#   'ORANGE',
#   'BUTTER',
#   'COKE',
#   'EGGS',
#   'MILK'],
#  ['COKE', 'ORANGE', 'COFFEE', 'RICE'],
#  ['MAGGI', 'COFFEE', 'BREAD', 'ORANGE', 'PEPPER', 'RICE', 'COKE'],
#  ['COFFEE', 'CORNFLAKES', 'JAM', 'MAGGI', 'BUTTER', 'EGGS'],
#  ['YOGURT', 'PEPPER', 'SALT'],
#  ['SALT', 'MAGGI', 'SUGAR', 'MILK', 'PEPPER'],
#  ['MILK', 'FLOUR', 'COFFEE', 'MAGGI', 'CORNFLAKES', 'RICE', 'BREAD', 'JAM'],
#  ['RICE', 'JAM', 'PEPPER', 'BUTTER', 'CORNFLAKES', 'ORANGE'],
#  ['BREAD', 'TEA', 'SALT', 'COFFEE', 'BUTTER', 'PEPPER'],
#  ['SUGAR', 'COFFEE', 'FLOUR', 'BUTTER', 'EGGS', 'RICE'],
#  ['BUTTER', 'BREAD', 'ORANGE', 'FLOUR', 'TEA', 'CORNFLAKES', 'RICE'],
#  ['COKE',
#   'YOGURT',
#   'BREAD',
#   'SALT',
#   'JAM',
#   'SUGAR',
#   'MAGGI',
#   'CORNFLAKES',
#   'TEA',
#   'MILK'],
#  ['BREAD', 'RICE', 'TEA', 'SUGAR', 'FLOUR', 'PEPPER', 'ORANGE', 'YOGURT'],
#  ['ORANGE', 'COFFEE', 'FLOUR', 'JAM', 'MILK'],
#  ['RICE', 'BREAD', 'YOGURT', 'MILK', 'SALT', 'ORANGE', 'FLOUR'],
#  ['MAGGI', 'SUGAR', 'BUTTER'],
#  ['RICE', 'BUTTER', 'TEA', 'MAGGI', 'BREAD'],
#  ['PEPPER',
#   'MILK',
#   'SALT',
#   'ORANGE',
#   'MAGGI',
#   'SUGAR',
#   'TEA',
#   'YOGURT',
#   'JAM',
#   'BUTTER'],
#  ['RICE', 'FLOUR', 'JAM', 'BREAD', 'EGGS', 'TEA'],
#  ['RICE',
#   'COKE',
#   'SALT',
#   'COFFEE',
#   'YOGURT',
#   'JAM',
#   'BREAD',
#   'MAGGI',
#   'SUGAR'],
#  ['EGGS', 'TEA', 'BUTTER', 'JAM', 'ORANGE', 'MILK', 'SALT', 'COKE', 'BREAD'],
#  ['ORANGE', 'SUGAR', 'YOGURT', 'EGGS', 'SALT', 'COFFEE', 'BUTTER'],
#  ['CORNFLAKES', 'FLOUR', 'YOGURT', 'RICE', 'ORANGE', 'TEA'],
#  ['BUTTER', 'COFFEE', 'MAGGI', 'PEPPER'],
#  ['SALT', 'CORNFLAKES', 'ORANGE', 'EGGS', 'SUGAR'],
#  ['EGGS', 'FLOUR', 'COFFEE', 'MAGGI', 'RICE', 'PEPPER', 'SALT'],
#  ...]

# %%
te = TransactionEncoder()
te_data = te.fit(product_data).transform(product_data)

model_data = pd.DataFrame(te_data,columns=te.columns_)
model_data
# Out:
#       BREAD  BUTTER  COFFEE   COKE  CORNFLAKES   EGGS  FLOUR    JAM  MAGGI  \
# 0     False    True    True   True       False  False  False  False  False
# 1     False   False   False  False       False  False  False  False   True
# 2     False    True   False  False        True  False   True  False  False
# 3      True   False   False  False        True  False  False   True   True
# 4     False    True   False   True       False   True  False  False   True
# ...     ...     ...     ...    ...         ...    ...    ...    ...    ...
# 9995  False    True   False   True        True   True  False  False  False
# 9996   True   False   False   True       False  False   True   True   True
# 9997  False   False    True  False       False  False   True   True  False
# 9998  False   False   False  False       False   True  False  False   True
# 9999   True    True   False   True       False  False  False   True  False
#
#        MILK  ORANGE  PEPPER   RICE   SALT  SUGAR    TEA  YOGURT
# 0     False    True   False  False  False  False  False    True
# 1     False    True   False  False   True  False  False   False
# 2     False   False   False  False  False   True   True   False
# 3     False   False   False  False  False   True  False   False
# 4      True   False   False   True  False   True  False    True
# ...     ...     ...     ...    ...    ...    ...    ...     ...
# 9995  False   False   False   True   True  False  False    True
# 9996  False    True    True  False  False  False   True    True
# 9997  False   False    True   True   True  False  False    True
# 9998   True   False   False  False  False  False  False   False
# 9999   True    True   False   True   True   True   True   False
#
# [10000 rows x 17 columns]

# %%
model_data.sum()
# Out:
# BREAD         3853
# BUTTER        3812
# COFFEE        3803
# COKE          3798
# CORNFLAKES    3803
# EGGS          3811
# FLOUR         3774
# JAM           3783
# MAGGI         3794
# MILK          3702
# ORANGE        3879
# PEPPER        3806
# RICE          3792
# SALT          3797
# SUGAR         3801
# TEA           3880
# YOGURT        3791
# dtype: int64

# %%
df_pattern = apriori(model_data, min_support=0.15, use_colnames=True)
df_pattern
# Out:
#     support        itemsets
# 0    0.3853         (BREAD)
# 1    0.3812        (BUTTER)
# 2    0.3803        (COFFEE)
# 3    0.3798          (COKE)
# 4    0.3803    (CORNFLAKES)
# ..      ...             ...
# 73   0.1531   (SALT, SUGAR)
# 74   0.1504     (SALT, TEA)
# 75   0.1506  (YOGURT, SALT)
# 76   0.1520    (TEA, SUGAR)
# 77   0.1567   (YOGURT, TEA)
#
# [78 rows x 2 columns]

# %%
association_rules(df_pattern, metric="confidence", min_threshold=0.10)
# Out:
#       antecedents   consequents  antecedent support  consequent support  \
# 0        (BUTTER)       (BREAD)              0.3812              0.3853
# 1         (BREAD)      (BUTTER)              0.3853              0.3812
# 2    (CORNFLAKES)       (BREAD)              0.3803              0.3853
# 3         (BREAD)  (CORNFLAKES)              0.3853              0.3803
# 4           (JAM)       (BREAD)              0.3783              0.3853
# ..            ...           ...                 ...                 ...
# 117        (SALT)      (YOGURT)              0.3797              0.3791
# 118         (TEA)       (SUGAR)              0.3880              0.3801
# 119       (SUGAR)         (TEA)              0.3801              0.3880
# 120      (YOGURT)         (TEA)              0.3791              0.3880
# 121         (TEA)      (YOGURT)              0.3880              0.3791
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 0     0.1524    0.399790  1.037607  0.005524    1.024142       0.058572
# 1     0.1524    0.395536  1.037607  0.005524    1.023717       0.058963
# 2     0.1558    0.409677  1.063266  0.009270    1.041294       0.096017
# 3     0.1558    0.404360  1.063266  0.009270    1.040394       0.096798
# 4     0.1540    0.407084  1.056539  0.008241    1.036741       0.086075
# ..       ...         ...       ...       ...         ...            ...
# 117   0.1506    0.396629  1.046238  0.006656    1.029052       0.071247
# 118   0.1520    0.391753  1.030657  0.004521    1.019158       0.048603
# 119   0.1520    0.399895  1.030657  0.004521    1.019821       0.047983
# 120   0.1567    0.413347  1.065328  0.009609    1.043207       0.098764
# 121   0.1567    0.403866  1.065328  0.009609    1.041544       0.100200
#
# [122 rows x 10 columns]
